# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install optuna

# %%
import pandas as pd
import numpy as np
import os
import random
from tqdm.auto import tqdm
import optuna

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings(action='ignore')

DATA_PATH = '/content/drive/MyDrive/데이터 분석/데이콘 캐글 컴페티션/예슬 개인 참가/대구 교통사고 피해 예측/data/'
SEED = 42

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
# !pip install ngboost

# %%
# Modeling & Tuning
from sklearn.model_selection import KFold
n_splits=5; seed = 42
kfold = KFold(n_splits=n_splits, shuffle=True, random_state=seed)
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
# from ngboost import NGBRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.model_selection import RandomizedSearchCV

# %%
train = pd.read_csv(f"{DATA_PATH}train.csv")

train_df = pd.read_csv(f"{DATA_PATH}train.csv")
test_df = pd.read_csv(f"{DATA_PATH}test.csv")
accident_df = pd.read_csv(f"{DATA_PATH}countrywide_accident.csv")
DG_cctv = pd.read_csv(f"{DATA_PATH}대구 CCTV 정보.csv", encoding='cp949')
DG_parking = pd.read_csv(f"{DATA_PATH}대구 주차장 정보.csv", encoding='cp949')
DG_children_area = pd.read_csv(f"{DATA_PATH}대구 어린이 보호 구역 정보.csv", encoding='cp949')
DG_seculight = pd.read_csv(f"{DATA_PATH}대구 보안등 정보.csv", encoding='cp949')
submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv")

# KR_cctv = pd.read_csv(f'{DATA_PATH}전국무인교통단속카메라표준데이터.csv', encoding='cp949')
# KR_seculight =pd.read_csv(f'{DATA_PATH}전국보안등정보표준데이터.csv', encoding='cp949')
# KR_children_area = pd.read_csv(f'{DATA_PATH}전국어린이보호구역표준데이터.csv', encoding='cp949')
# KR_parking = pd.read_csv(f'{DATA_PATH}전국주차장정보표준데이터.csv', encoding='cp949')

# train_df.shape, test_df.shape

# DATA_PATH = '/kaggle/input/daegu-dataset-2/'

# train = pd.read_csv(f"{DATA_PATH}train.csv")

# train_df = pd.read_csv(f"{DATA_PATH}train.csv")
# test_df = pd.read_csv(f"{DATA_PATH}test.csv")
# accident_df = pd.read_csv(f"{DATA_PATH}countrywide_accident.csv")
# DG_cctv = pd.read_csv(f"{DATA_PATH}DG_cctv.csv", encoding='cp949')
# DG_parking = pd.read_csv(f"{DATA_PATH}DG_parking.csv", encoding='cp949')
# DG_children_area = pd.read_csv(f"{DATA_PATH}DG_children_area.csv", encoding='cp949')
# DG_seculight = pd.read_csv(f"{DATA_PATH}DG_seculight.csv", encoding='cp949')
# submission = pd.read_csv(f"{DATA_PATH}sample_submission.csv")

# DATA_PATH = '/kaggle/input/daegu-kr-dataset/'

# KR_cctv = pd.read_csv(f'{DATA_PATH}KR_cctv.csv', encoding='cp949')
# KR_seculight =pd.read_csv(f'{DATA_PATH}KR_seculight.csv', encoding='cp949')
# KR_children_area = pd.read_csv(f'{DATA_PATH}KR_children_area.csv', encoding='cp949')
# KR_parking = pd.read_csv(f'{DATA_PATH}KR_parking.csv', encoding='cp949')

train_df.shape, test_df.shape
# Out:
# ((39609, 23), (10963, 8))

# %%
# # 안개 삭제
# train.drop(train[train['기상상태'] == '안개'].index, inplace=True)
# accident_df.drop(accident_df[accident_df['기상상태'] == '안개'].index, inplace=True)

# # 해빙, nan 삭제
# accident_df.drop(accident_df[accident_df['노면상태'] == '해빙'].index, inplace=True)
# accident_df.drop(accident_df[accident_df['노면상태'].isnull()].index, inplace=True)

# # 철길건널목 삭제
# accident_df.drop(accident_df[accident_df['사고유형'] == '철길건널목'].index, inplace=True)

# %%
train_df = pd.concat([train, accident_df], axis=0).reset_index().drop(columns='index')

# %%
location_pattern = r'(\S+) (\S+) (\S+)'

train_df[['도시', '구', '동']] = train_df['시군구'].str.extract(location_pattern)
train_df = train_df.drop(columns=['시군구'])

# test 데이터 반영
test_df[['도시', '구', '동']] = test_df['시군구'].str.extract(location_pattern)
test_df = test_df.drop(columns=['시군구'])

# %%
road_pattern = r'(.+) - (.+)'

train_df[['도로형태1', '도로형태2']] = train_df['도로형태'].str.extract(road_pattern)
train_df = train_df.drop(columns=['도로형태'])

# test 데이터 반영
test_df[['도로형태1', '도로형태2']] = test_df['도로형태'].str.extract(road_pattern)
test_df = test_df.drop(columns=['도로형태'])

# %%
# 동별 연별 총부상수의 평균
# 연별 치사율의 평균

# %%
# train_df['도시'].unique().tolist()

# drop_region = ['서울특별시','제주특별자치도','세종특별자치시','미분류','nan']

# mask = ~train_df['도시'].isin(drop_region)
# train_df = train_df[mask].reset_index().drop(columns='index')


# drop_region = ['서울특별시','제주특별자치도','세종특별자치시','미분류','nan']
gwangyuk = ['대구광역시','인천광역시','광주광역시','부산광역시','울산광역시','대전광역시']

mask = train_df['도시'].isin(gwangyuk)
train_df = train_df[mask].reset_index().drop(columns='index')

# %%
train_df.columns.tolist()
# Out:
# ['ID',
#  '사고일시',
#  '요일',
#  '기상상태',
#  '노면상태',
#  '사고유형',
#  '사고유형 - 세부분류',
#  '법규위반',
#  '가해운전자 차종',
#  '가해운전자 성별',
#  '가해운전자 연령',
#  '가해운전자 상해정도',
#  '피해운전자 차종',
#  '피해운전자 성별',
#  '피해운전자 연령',
#  '피해운전자 상해정도',
#  '사망자수',
#  '중상자수',
#  '경상자수',
#  '부상자수',
#  'ECLO',
#  '도시',
#  '구',
#  '동',
#  '도로형태1',
#  '도로형태2']

# %% [markdown]
# # Feature 실험

# %% [markdown]
# ### 시간추가

# %%
import holidays
kr_holidays = holidays.KR()
# 시간 관련
train_df['date'] = pd.to_datetime(train_df['사고일시'])
train_df['연'] = train_df['date'].dt.year.astype(int)
train_df['월'] = train_df['date'].dt.month.astype(int)
train_df['일'] = train_df['date'].dt.day.astype(int)
train_df['시간'] = train_df['date'].dt.hour.astype(int)
train_df['요일'] = train_df['date'].dt.day_of_week.astype(int)
train_df['공휴일'] = train_df['date'].apply(lambda x : int(x in kr_holidays)).astype(int)

test_df['date'] = pd.to_datetime(test_df['사고일시'])
test_df['연'] = test_df['date'].dt.year.astype(int)
test_df['월'] = test_df['date'].dt.month.astype(int)
test_df['일'] = test_df['date'].dt.day.astype(int)
test_df['시간'] = test_df['date'].dt.hour.astype(int)
test_df['요일'] = test_df['date'].dt.day_of_week.astype(int)
test_df['공휴일'] = test_df['date'].apply(lambda x : int(x in kr_holidays)).astype(int)

train_df = train_df.drop(columns=['사고일시','date'])
test_df = test_df.drop(columns=['사고일시','date'])

# %% [markdown]
# ### 총부상자

# %%
train_df['월동_총부상자'] = train_df['사망자수'] + train_df['중상자수'] + train_df['경상자수'] + train_df['부상자수']

casualty = train_df.groupby(['월','도시','구','동'])[['월동_총부상자']].mean().reset_index()
train_df = train_df.drop(columns = '월동_총부상자')

train_df = pd.merge(train_df,casualty, on = ['월','도시','구','동'], how='left')
test_df = pd.merge(test_df,casualty, on = ['월','도시','구','동'], how='left')

# %% [markdown]
# ### eclo mean

# %%
tmp = train_df.groupby(['시간','요일'])[['ECLO']].mean().reset_index()
tmp.columns = ['시간','요일','ECLO_mean']

train_df = train_df.merge(tmp, on= ['시간','요일'], how='left')
test_df = test_df.merge(tmp, on= ['시간','요일'], how='left')

# %% [markdown]
# ### train only

# %%
# train_ft1 = pd.concat([train,accident_df], axis= 0).reset_index()

train_ft1 = train

# %%
# 시간
train_ft1['date'] = pd.to_datetime(train_ft1['사고일시'])
train_ft1['연'] = train_ft1['date'].dt.year.astype(int)
train_ft1['월'] = train_ft1['date'].dt.month.astype(int)
train_ft1['일'] = train_ft1['date'].dt.day.astype(int)
train_ft1['시간'] = train_ft1['date'].dt.hour.astype(int)
train_ft1['요일'] = train_ft1['date'].dt.day_of_week.astype(int)

# 시군구
location_pattern = r'(\S+) (\S+) (\S+)'
train_ft1[['도시', '구', '동']] = train_ft1['시군구'].str.extract(location_pattern)
train_ft1 = train_ft1.drop(columns=['시군구'])

# 도로형태

road_pattern = r'(.+) - (.+)'
train_ft1[['도로형태1', '도로형태2']] = train_ft1['도로형태'].str.extract(road_pattern)
train_ft1 = train_ft1.drop(columns=['도로형태'])

# %%
def categorize_time_period(hour):
    if 6 <= hour < 9:  # 아침 출퇴근 시간
        return 0
    elif 9 <= hour < 12:  # 아침
        return 1
    elif 12 <= hour < 14:  # 점심
        return 2
    elif 14 <= hour < 18:  # 오후
        return 3
    elif 18 <= hour < 21:  # 저녁
        return 4
    elif 21 <= hour < 24:  # 밤
        return 5
    else:  # 새벽
        return 6

train_ft1['시간대'] = train_ft1['시간'].apply(categorize_time_period)

train_df['시간대'] = train_df['시간'].apply(categorize_time_period)
test_df['시간대'] = test_df['시간'].apply(categorize_time_period)

# %%
df = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].mean().reset_index()
df0 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].count().reset_index().iloc[:,1:]
df1 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].sum().reset_index().iloc[:,1:]
df2 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].min().reset_index().iloc[:,1:]
df3 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].max().reset_index().iloc[:,1:]
df4 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].median().reset_index().iloc[:,1:]
df5 = train_ft1.groupby(['가해운전자 차종'])[['ECLO']].std().reset_index().iloc[:,1:]


df_acc = pd.concat([df, df4,df0, df1, df2, df3, df5], axis=1)
df_acc.columns = ['가해운전자 차종','median','mean','count','sum','min','max','std']
# df_acc['max_mean'] = df_acc['max'] * df_acc['mean']
# df_acc['max_median'] = df_acc['max'] * df_acc['median']
# df_acc['max_std'] = df_acc['max'] * df_acc['std']
# df_acc['mean_median'] = df_acc['mean'] * df_acc['median']
# df_acc['max_count'] = df_acc['max'] * (df_acc['count'])
# df_acc['max_count_medianmean'] = df_acc['max'] * df_acc['count'] * (df_acc['mean'] + df_acc['median'])/2
# df_acc['max_count_log'] = df_acc['max'] * np.log(df_acc['count'])
# df_acc['max_count_log_mean_log'] = df_acc['max'] * np.log(df_acc['count']) *np.log(df_acc['mean'])
# df_acc['count_log_median'] = np.log(df_acc['count']) * df_acc['median']
# df_acc['max_count_log_median'] = df_acc['max'] * np.log(df_acc['count']) *df_acc['median']
# df_acc['max_count_log_mean'] = df_acc['max'] * np.log(df_acc['count']) *df_acc['mean']
df_acc['max_std_count_log'] = df_acc['max'] * np.log(df_acc['count']) *df_acc['std']


# max count_log의 조합을 기준으로 정렬해서 라벨 인코딩 (비슷한 범주가 라벨링된다는 가정하에 범주를 평균할 수 있으므로)
df_acc = df_acc.sort_values(by='max_std_count_log', ascending=False)
# display(df_acc)

df_cols = df_acc['가해운전자 차종'].tolist()

label_mapping = {label: index for index, label in enumerate(df_cols)}
train_ft1['가해운전자 차종_sorted'] = train_ft1['가해운전자 차종'].map(label_mapping).astype(int)

# for col in train_ft1[['가해운전자 차종_sorted', '가해운전자 차종']]:
#     sns.scatterplot(x=train_ft1[col], y=train_ft1['ECLO'])
#     break

# %%
df = train_ft1.groupby(['구','시간대','요일','사고유형','도로형태2'])[['가해운전자 차종_sorted']].mean().reset_index()
df
# Out:
#        구  시간대  요일  사고유형     도로형태2  가해운전자 차종_sorted
# 0     남구    0   0  차대사람     교차로부근         1.000000
# 1     남구    0   0  차대사람  교차로횡단보도내         1.000000
# 2     남구    0   0  차대사람        기타         3.200000
# 3     남구    0   0  차대사람       주차장         2.000000
# 4     남구    0   0   차대차     교차로부근         2.833333
# ...   ..  ...  ..   ...       ...              ...
# 3775  중구    6   6   차대차        교량         2.000000
# 3776  중구    6   6   차대차     교차로부근         2.000000
# 3777  중구    6   6   차대차      교차로안         2.142857
# 3778  중구    6   6   차대차        기타         2.304348
# 3779  중구    6   6  차량단독     교차로부근         3.000000
#
# [3780 rows x 6 columns]

# %%
train_df = pd.merge(train_df,df, on = ['구','시간대','요일','사고유형','도로형태2'], how='left')
test_df = pd.merge(test_df,df, on = ['구','시간대','요일','사고유형','도로형태2'], how='left')

# %%
df = train_ft1.groupby(['피해운전자 상해정도'])[['ECLO']].mean().reset_index()
df1 = train_ft1.groupby(['피해운전자 상해정도'])[['ECLO']].min().reset_index().iloc[:,1:]

df_acc = pd.concat([df,df1], axis=1)
df_acc.columns = ['피해운전자 상해정도','mean','min']
df_acc = df_acc.sort_values(by='min', ascending=False)

df_cols = df_acc['피해운전자 상해정도'].tolist()

label_mapping = {label: index for index, label in enumerate(df_cols)}
train_ft1['피해운전자 상해정도_sorted'] = train_ft1['피해운전자 상해정도'].map(label_mapping)

# for col in train_ft1[['피해운전자 상해정도_sorted', '피해운전자 상해정도']]:
#     sns.scatterplot(x=train_ft1[col], y=train_ft1['ECLO'])
#     break

# %%
df = train_ft1.groupby(['구','시간대','요일','사고유형','도로형태2'])[['피해운전자 상해정도_sorted']].mean().reset_index()
df
# Out:
#        구  시간대  요일  사고유형     도로형태2  피해운전자 상해정도_sorted
# 0     남구    0   0  차대사람     교차로부근           2.000000
# 1     남구    0   0  차대사람  교차로횡단보도내           1.000000
# 2     남구    0   0  차대사람        기타           3.200000
# 3     남구    0   0  차대사람       주차장           2.000000
# 4     남구    0   0   차대차     교차로부근           2.500000
# ...   ..  ...  ..   ...       ...                ...
# 3775  중구    6   6   차대차        교량           2.000000
# 3776  중구    6   6   차대차     교차로부근           2.285714
# 3777  중구    6   6   차대차      교차로안           2.000000
# 3778  중구    6   6   차대차        기타           2.391304
# 3779  중구    6   6  차량단독     교차로부근                NaN
#
# [3780 rows x 6 columns]

# %%
train_df = pd.merge(train_df,df, on = ['구','시간대','요일','사고유형','도로형태2'], how='left')
test_df = pd.merge(test_df,df, on = ['구','시간대','요일','사고유형','도로형태2'], how='left')

# %%
train_df = train_df.drop(columns = '시간대')
test_df = test_df.drop(columns = '시간대')

# %% [markdown]
# # 인코딩, 스케일링

# %%
train_df = train_df.fillna(0)
test_df = test_df.fillna(0)

# %%
train_df.columns.tolist()
# Out:
# ['ID',
#  '요일',
#  '기상상태',
#  '노면상태',
#  '사고유형',
#  '사고유형 - 세부분류',
#  '법규위반',
#  '가해운전자 차종',
#  '가해운전자 성별',
#  '가해운전자 연령',
#  '가해운전자 상해정도',
#  '피해운전자 차종',
#  '피해운전자 성별',
#  '피해운전자 연령',
#  '피해운전자 상해정도',
#  '사망자수',
#  '중상자수',
#  '경상자수',
#  '부상자수',
#  'ECLO',
#  '도시',
#  '구',
#  '동',
#  '도로형태1',
#  '도로형태2',
#  '연',
#  '월',
#  '일',
#  '시간',
#  '공휴일',
#  '월동_총부상자',
#  'ECLO_mean',
#  '가해운전자 차종_sorted',
#  '피해운전자 상해정도_sorted']

# %%
test_x = test_df.drop(columns = ['ID','도시'])
train_x = train_df[test_x.columns]

train_y = train_df['ECLO']

# %%
num_cols = train_x.select_dtypes(exclude='object').columns.tolist()
num_cols
# Out:
# ['요일',
#  '연',
#  '월',
#  '일',
#  '시간',
#  '공휴일',
#  '월동_총부상자',
#  'ECLO_mean',
#  '가해운전자 차종_sorted',
#  '피해운전자 상해정도_sorted']

# %%
cat_cols = train_x.select_dtypes(include='object').columns.tolist()
cat_cols
# Out:
# ['기상상태', '노면상태', '사고유형', '구', '동', '도로형태1', '도로형태2']

# %%
cat_cols
# 시간, 공간 정보 이외 모두 one hot encoding

cat_cols1 = ['요일','구','동']
cat_cols2 = [col for col in cat_cols if col not in cat_cols1]
cat_cols2
# Out:
# ['기상상태', '노면상태', '사고유형', '도로형태1', '도로형태2']

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
import category_encoders as ce

one_hot = OneHotEncoder()
label = LabelEncoder()
ordinal = OrdinalEncoder()
target_enc = ce.TargetEncoder()

# %%
train_x[cat_cols1] = train_x[cat_cols1].astype(str)

# %%
# cols1 라벨인코딩
for col in cat_cols1 :
    train_x[col] = target_enc.fit_transform(train_x[col],train_y)
    test_x[col] = target_enc.transform(test_x[col])

# %%
train_x[cat_cols2] = train_x[cat_cols2].astype(str)

# %%
# cols 2 원핫인코딩
tmp = pd.DataFrame(one_hot.fit_transform(train_x[cat_cols2]).toarray())
tmp.columns = one_hot.get_feature_names_out()
pd.DataFrame(tmp)

train_x = pd.concat([train_x,tmp],axis=1).drop(columns= cat_cols2)

tmp = pd.DataFrame(one_hot.fit_transform(test_x[cat_cols2]).toarray())
tmp.columns = one_hot.get_feature_names_out()
pd.DataFrame(tmp)

test_x = pd.concat([test_x,tmp],axis=1).drop(columns= cat_cols2)

train_x.shape, test_x.shape
# Out:
# ((158959, 45), (10963, 41))

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaler = StandardScaler()

# train_df[num_cols] = scaler.fit_transform(train_df[num_cols])
# test_df[num_cols] = scaler.transform(test_df[num_cols])

scaler = StandardScaler()

train_x[num_cols] = scaler.fit_transform(train_x[num_cols])
test_x[num_cols] = scaler.transform(test_x[num_cols])

# %%
train_x = train_x[test_x.columns]
train_x.shape, test_x.shape
# Out:
# ((158959, 41), (10963, 41))

# %% [markdown]
# # 검증 및 평가

# %%
# target = np.log1p(train_y)
# target = train_y

# %%
import re
train_x = train_x.rename(columns = lambda x:re.sub('[^가-힣A-Za-z0-9_]+', '', x))
test_x = test_x.rename(columns = lambda x:re.sub('[^가-힣A-Za-z0-9_]+', '', x))

# %%
from sklearn.metrics import make_scorer

def rmsle(y_actual, y_pred):
    diff = np.log1p(y_pred) - np.log1p(y_actual)
    mean_error = np.mean(np.square(diff))

    return np.sqrt(mean_error)

rmsle_score = make_scorer(rmsle, greater_is_better=False)

# %%
# -0.15797365915856704
lgbm_best_params = {'n_estimators': 1178, 'num_leaves': 30, 'max_depth': 6, 'learning_rate': 0.011407608181541297, 'feature_fraction': 0.8545377839510566, 'bagging_fraction': 0.17429104930042236, 'lambda_l1': 6.529596581208154, 'lambda_l2': 8.837614837937567, 'min_child_samples': 59}

# -0.15789535340990057
cat_best_params = {'n_estimators': 1179, 'depth': 7, 'learning_rate': 0.02164558958549747, 'l2_leaf_reg': 3.0882038843672674}

# -0.4180133168978298
xgb_best_params = {'n_estimators': 3241, 'max_depth': 24, 'learning_rate': 0.024010747652112696, 'gamma': 0.7071727358928532, 'min_child_weight': 2, 'subsample': 0.8062272924485435, 'colsample_bytree': 0.8429061023478192, 'reg_alpha': 0.1812908822349264, 'reg_lambda': 1.7344690669541394}

# %%
train_x.shape, test_x.shape
# Out:
# ((158959, 41), (10963, 41))

# %% [markdown]
# # 시드앙상블

# %% [markdown]
# - lgbm kfold, seed ensemble

# %%
[700, 560, 586, 542, 80, 190, 786, 267, 839, 221, 537, 353, 575, 104, 12, 561, 4, 916, 707, 21, 366, 130, 286, 101, 476, 226, 693, 297, 673, 203, 944, 64, 609, 75, 242, 167, 305, 352, 871, 0, 136, 697, 983, 440, 872, 402, 284, 819, 742, 584, 241, 74, 606, 462, 868, 88, 205, 978, 212, 675, 842, 84, 737, 557, 533, 778, 82, 680, 900, 121, 721, 820, 745, 377, 801, 690, 890, 743, 644, 2, 709, 473, 189, 547, 465, 932, 782, 230, 695, 279, 974, 747, 500, 9, 362, 413, 956, 719, 449, 414, 410, 456, 658, 924, 251, 661, 389, 724, 954, 269, 808, 204, 56, 308, 331, 861, 681, 527, 846, 906, 741, 273, 154, 349, 794, 780, 829, 243, 22, 291, 164, 403, 672, 445, 498, 468, 774, 793, 227, 244, 486, 354, 811, 55, 694, 564, 424, 665, 570, 705, 400, 821, 590, 513, 580, 950, 271, 312, 195, 268, 161, 119, 313, 763, 467, 109, 329, 289, 824, 41, 652, 333, 512, 157, 496, 338, 687, 1, 992, 826, 148, 637, 691, 996, 688, 8, 95, 543, 797, 980, 749, 117, 897, 100, 504, 883, 562, 53, 67, 597, 683, 601, 408, 708, 309, 859, 613, 364, 248, 910, 852, 206, 337, 134, 788, 3, 26, 654, 263, 999, 898, 123, 407, 804, 614, 341, 270, 881, 735, 854, 323, 765, 961, 507, 24, 208, 679, 632, 10, 830, 619, 168, 185, 127, 604, 45, 96, 832, 668, 236, 207, 914, 835, 633, 511, 655, 857, 129, 809, 785, 406, 686, 739, 380, 32, 392, 452, 639, 873, 494, 225, 131, 153, 891, 796, 17, 588, 594, 200, 659, 143, 524, 63, 47, 213, 703, 522, 438, 607, 893, 103, 546, 696, 180, 946, 172, 568, 844, 461, 657, 939, 495, 361, 874, 753, 955, 249, 184, 554, 718, 20, 953, 958, 343, 689, 146, 731, 803, 716, 427, 882, 934, 752, 388, 738, 825, 429, 663, 152, 278, 518, 565, 636, 904, 30, 592, 298, 666, 887, 977, 156, 368, 58, 39, 903, 381, 630, 479, 558, 85, 78, 509, 768, 31, 105, 257, 275, 754, 15, 335, 787, 927, 949, 296, 426, 219, 194, 118, 319, 698, 845, 165, 641, 351, 162, 192, 940, 585, 128, 166, 576, 304, 987, 772, 751, 375, 608, 223, 795, 348, 766, 191, 965, 282, 401, 602, 149, 629, 137, 124, 69, 583, 235, 33, 621, 451, 358, 998, 761, 34, 133, 272, 888, 853, 538, 593, 422, 624, 722, 201, 938, 869, 610, 937, 466, 214, 404, 469, 798, 662, 833, 984, 489, 508, 913, 671, 464, 38, 577, 600, 627, 110, 497, 529, 446, 390, 425, 574, 183, 176, 544, 376, 28, 65, 638, 170, 140, 779, 48, 993, 589, 135, 862, 66, 316, 506, 158, 653, 968, 642, 783, 411, 173, 677, 453, 306, 572, 918, 595, 29, 837, 730, 911, 493, 715, 523, 471, 748, 781, 647, 218, 651, 247, 892, 860, 16, 643, 310, 750, 346, 345, 899, 567, 463, 199, 775, 42, 907, 634, 770, 746, 670, 552, 14, 896, 211, 676, 367, 902, 726, 385, 5, 915, 334, 935, 474, 439, 320, 262, 648, 503, 923, 929, 266, 678, 187, 443, 838, 941, 294, 371, 909, 327, 488, 19, 355, 280, 336, 40, 975, 382, 514, 339, 264, 936, 428, 256, 617, 240, 650, 962, 800, 713, 475, 484, 59, 370, 314, 36, 587, 102, 791, 640, 556, 843, 125, 92, 945, 813, 415, 501, 325, 712, 342, 113, 776, 849, 87, 920, 994, 224, 307, 549, 480, 423, 328, 947, 528, 285, 841, 393, 951, 858, 531, 311, 147, 967, 115, 37, 535, 492, 300, 598, 254, 656, 237, 591, 720, 79, 23, 815, 485, 210, 197, 13, 880, 827, 434, 35, 169, 863, 369, 790, 108, 816, 442, 441, 112, 437, 972, 419, 460, 238, 179, 477, 432, 931, 550, 701, 649, 948, 894, 295, 823, 732, 175, 699, 188, 132, 344, 925, 246, 986, 525, 81, 714, 840, 966, 265, 216, 57, 160, 867, 612, 27, 76, 885, 886, 138, 875, 878, 181, 470, 99, 895, 91, 622, 628, 472, 499, 60, 420, 979, 985, 163, 521, 398, 482, 603, 520, 317, 532, 454, 71, 646, 318, 384, 487, 704, 773, 917, 365, 142, 530, 545, 879, 144, 912, 851, 759, 807, 828, 245, 526, 458, 232, 855, 222, 94, 908, 394, 767, 151, 817, 89, 287, 357, 777, 330, 18, 483, 51, 921, 582, 631, 664, 517, 274, 252, 995, 901, 171, 186, 717, 727, 478, 277, 905, 83, 293, 519, 834, 228, 120, 276, 444, 674, 534, 11, 734, 386, 259, 711, 86, 573, 324, 490, 725, 645, 326, 116, 374, 964, 831, 599, 383, 789, 54, 229, 182, 233, 258, 363, 302, 459, 505, 952, 290, 356, 360, 253, 373, 702, 615, 988, 571, 755, 970, 973, 418, 159, 990, 516, 684, 231, 818, 733, 706, 744, 502, 359, 450, 448, 97, 623, 616, 288, 322, 72, 771, 61, 399, 926, 579, 836, 976, 49, 991, 536, 864, 283, 884, 930, 396, 25, 848, 255, 433, 710, 578, 491, 758, 417, 193, 215, 870, 261, 457, 126, 391, 784, 46, 762, 141, 769, 928, 220, 792, 260, 682, 44, 806, 919, 315, 812, 6, 209, 409, 581, 303, 740, 865, 822, 963, 729, 802, 856, 111, 387, 723, 340, 933, 728, 90, 997, 563, 764, 969, 73, 635, 922, 847, 539, 202, 960, 605, 217, 379, 435, 436, 957, 551, 178, 52, 971, 685, 515, 332, 566, 7, 68, 510, 618, 412, 421, 431, 299, 620, 877, 981, 540, 106, 757, 281, 810, 114, 559, 889, 177, 799, 292, 405, 43, 155, 736, 760, 943, 555, 139, 667, 98, 234, 669, 397, 447, 481, 756, 455, 626, 548, 196, 625, 866, 62, 372, 850, 569, 416, 553, 350, 989, 301, 93, 250, 321, 660, 596, 395, 77, 174, 814, 150, 541, 611, 122, 107, 959, 347, 430, 198, 876, 70, 378, 805, 942, 692, 239, 982, 145, 50]
# [0.4302101095577636, 0.4302110921242101, 0.4302126412764012, 0.43021670228641773, 0.4302175290755098,
# Out:
# [700,
#  560,
#  586,
#  542,
#  80,
#  190,
#  786,
#  267,
#  839,
#  221,
#  537,
#  353,
#  575,
#  104,
#  12,
#  561,
#  4,
#  916,
#  707,
#  21,
#  366,
#  130,
#  286,
#  101,
#  476,
#  226,
#  693,
#  297,
#  673,
#  203,
#  944,
#  64,
#  609,
#  75,
#  242,
#  167,
#  305,
#  352,
#  871,
#  0,
#  136,
#  697,
#  983,
#  440,
#  872,
#  402,
#  284,
#  819,
#  742,
#  584,
#  241,
#  74,
#  606,
#  462,
#  868,
#  88,
#  205,
#  978,
#  212,
#  675,
#  842,
#  84,
#  737,
#  557,
#  533,
#  778,
#  82,
#  680,
#  900,
#  121,
#  721,
#  820,
#  745,
#  377,
#  801,
#  690,
#  890,
#  743,
#  644,
#  2,
#  709,
#  473,
#  189,
#  547,
#  465,
#  932,
#  782,
#  230,
#  695,
#  279,
#  974,
#  747,
#  500,
#  9,
#  362,
#  413,
#  956,
#  719,
#  449,
#  414,
#  410,
#  456,
#  658,
#  924,
#  251,
#  661,
#  389,
#  724,
#  954,
#  269,
#  808,
#  204,
#  56,
#  308,
#  331,
#  861,
#  681,
#  527,
#  846,
#  906,
#  741,
#  273,
#  154,
#  349,
#  794,
#  780,
#  829,
#  243,
#  22,
#  291,
#  164,
#  403,
#  672,
#  445,
#  498,
#  468,
#  774,
#  793,
#  227,
#  244,
#  486,
#  354,
#  811,
#  55,
#  694,
#  564,
#  424,
#  665,
#  570,
#  705,
#  400,
#  821,
#  590,
#  513,
#  580,
#  950,
#  271,
#  312,
#  195,
#  268,
#  161,
#  119,
#  313,
#  763,
#  467,
#  109,
#  329,
#  289,
#  824,
#  41,
#  652,
#  333,
#  512,
#  157,
#  496,
#  338,
#  687,
#  1,
#  992,
#  826,
#  148,
#  637,
#  691,
#  996,
#  688,
#  8,
#  95,
#  543,
#  797,
#  980,
#  749,
#  117,
#  897,
#  100,
#  504,
#  883,
#  562,
#  53,
#  67,
#  597,
#  683,
#  601,
#  408,
#  708,
#  309,
#  859,
#  613,
#  364,
#  248,
#  910,
#  852,
#  206,
#  337,
#  134,
#  788,
#  3,
#  26,
#  654,
#  263,
#  999,
#  898,
#  123,
#  407,
#  804,
#  614,
#  341,
#  270,
#  881,
#  735,
#  854,
#  323,
#  765,
#  961,
#  507,
#  24,
#  208,
#  679,
#  632,
#  10,
#  830,
#  619,
#  168,
#  185,
#  127,
#  604,
#  45,
#  96,
#  832,
#  668,
#  236,
#  207,
#  914,
#  835,
#  633,
#  511,
#  655,
#  857,
#  129,
#  809,
#  785,
#  406,
#  686,
#  739,
#  380,
#  32,
#  392,
#  452,
#  639,
#  873,
#  494,
#  225,
#  131,
#  153,
#  891,
#  796,
#  17,
#  588,
#  594,
#  200,
#  659,
#  143,
#  524,
#  63,
#  47,
#  213,
#  703,
#  522,
#  438,
#  607,
#  893,
#  103,
#  546,
#  696,
#  180,
#  946,
#  172,
#  568,
#  844,
#  461,
#  657,
#  939,
#  495,
#  361,
#  874,
#  753,
#  955,
#  249,
#  184,
#  554,
#  718,
#  20,
#  953,
#  958,
#  343,
#  689,
#  146,
#  731,
#  803,
#  716,
#  427,
#  882,
#  934,
#  752,
#  388,
#  738,
#  825,
#  429,
#  663,
#  152,
#  278,
#  518,
#  565,
#  636,
#  904,
#  30,
#  592,
#  298,
#  666,
#  887,
#  977,
#  156,
#  368,
#  58,
#  39,
#  903,
#  381,
#  630,
#  479,
#  558,
#  85,
#  78,
#  509,
#  768,
#  31,
#  105,
#  257,
#  275,
#  754,
#  15,
#  335,
#  787,
#  927,
#  949,
#  296,
#  426,
#  219,
#  194,
#  118,
#  319,
#  698,
#  845,
#  165,
#  641,
#  351,
#  162,
#  192,
#  940,
#  585,
#  128,
#  166,
#  576,
#  304,
#  987,
#  772,
#  751,
#  375,
#  608,
#  223,
#  795,
#  348,
#  766,
#  191,
#  965,
#  282,
#  401,
#  602,
#  149,
#  629,
#  137,
#  124,
#  69,
#  583,
#  235,
#  33,
#  621,
#  451,
#  358,
#  998,
#  761,
#  34,
#  133,
#  272,
#  888,
#  853,
#  538,
#  593,
#  422,
#  624,
#  722,
#  201,
#  938,
#  869,
#  610,
#  937,
#  466,
#  214,
#  404,
#  469,
#  798,
#  662,
#  833,
#  984,
#  489,
#  508,
#  913,
#  671,
#  464,
#  38,
#  577,
#  600,
#  627,
#  110,
#  497,
#  529,
#  446,
#  390,
#  425,
#  574,
#  183,
#  176,
#  544,
#  376,
#  28,
#  65,
#  638,
#  170,
#  140,
#  779,
#  48,
#  993,
#  589,
#  135,
#  862,
#  66,
#  316,
#  506,
#  158,
#  653,
#  968,
#  642,
#  783,
#  411,
#  173,
#  677,
#  453,
#  306,
#  572,
#  918,
#  595,
#  29,
#  837,
#  730,
#  911,
#  493,
#  715,
#  523,
#  471,
#  748,
#  781,
#  647,
#  218,
#  651,
#  247,
#  892,
#  860,
#  16,
#  643,
#  310,
#  750,
#  346,
#  345,
#  899,
#  567,
#  463,
#  199,
#  775,
#  42,
#  907,
#  634,
#  770,
#  746,
#  670,
#  552,
#  14,
#  896,
#  211,
#  676,
#  367,
#  902,
#  726,
#  385,
#  5,
#  915,
#  334,
#  935,
#  474,
#  439,
#  320,
#  262,
#  648,
#  503,
#  923,
#  929,
#  266,
#  678,
#  187,
#  443,
#  838,
#  941,
#  294,
#  371,
#  909,
#  327,
#  488,
#  19,
#  355,
#  280,
#  336,
#  40,
#  975,
#  382,
#  514,
#  339,
#  264,
#  936,
#  428,
#  256,
#  617,
#  240,
#  650,
#  962,
#  800,
#  713,
#  475,
#  484,
#  59,
#  370,
#  314,
#  36,
#  587,
#  102,
#  791,
#  640,
#  556,
#  843,
#  125,
#  92,
#  945,
#  813,
#  415,
#  501,
#  325,
#  712,
#  342,
#  113,
#  776,
#  849,
#  87,
#  920,
#  994,
#  224,
#  307,
#  549,
#  480,
#  423,
#  328,
#  947,
#  528,
#  285,
#  841,
#  393,
#  951,
#  858,
#  531,
#  311,
#  147,
#  967,
#  115,
#  37,
#  535,
#  492,
#  300,
#  598,
#  254,
#  656,
#  237,
#  591,
#  720,
#  79,
#  23,
#  815,
#  485,
#  210,
#  197,
#  13,
#  880,
#  827,
#  434,
#  35,
#  169,
#  863,
#  369,
#  790,
#  108,
#  816,
#  442,
#  441,
#  112,
#  437,
#  972,
#  419,
#  460,
#  238,
#  179,
#  477,
#  432,
#  931,
#  550,
#  701,
#  649,
#  948,
#  894,
#  295,
#  823,
#  732,
#  175,
#  699,
#  188,
#  132,
#  344,
#  925,
#  246,
#  986,
#  525,
#  81,
#  714,
#  840,
#  966,
#  265,
#  216,
#  57,
#  160,
#  867,
#  612,
#  27,
#  76,
#  885,
#  886,
#  138,
#  875,
#  878,
#  181,
#  470,
#  99,
#  895,
#  91,
#  622,
#  628,
#  472,
#  499,
#  60,
#  420,
#  979,
#  985,
#  163,
#  521,
#  398,
#  482,
#  603,
#  520,
#  317,
#  532,
#  454,
#  71,
#  646,
#  318,
#  384,
#  487,
#  704,
#  773,
#  917,
#  365,
#  142,
#  530,
#  545,
#  879,
#  144,
#  912,
#  851,
#  759,
#  807,
#  828,
#  245,
#  526,
#  458,
#  232,
#  855,
#  222,
#  94,
#  908,
#  394,
#  767,
#  151,
#  817,
#  89,
#  287,
#  357,
#  777,
#  330,
#  18,
#  483,
#  51,
#  921,
#  582,
#  631,
#  664,
#  517,
#  274,
#  252,
#  995,
#  901,
#  171,
#  186,
#  717,
#  727,
#  478,
#  277,
#  905,
#  83,
#  293,
#  519,
#  834,
#  228,
#  120,
#  276,
#  444,
#  674,
#  534,
#  11,
#  734,
#  386,
#  259,
#  711,
#  86,
#  573,
#  324,
#  490,
#  725,
#  645,
#  326,
#  116,
#  374,
#  964,
#  831,
#  599,
#  383,
#  789,
#  54,
#  229,
#  182,
#  233,
#  258,
#  363,
#  302,
#  459,
#  505,
#  952,
#  290,
#  356,
#  360,
#  253,
#  373,
#  702,
#  615,
#  988,
#  571,
#  755,
#  970,
#  973,
#  418,
#  159,
#  990,
#  516,
#  684,
#  231,
#  818,
#  733,
#  706,
#  744,
#  502,
#  359,
#  450,
#  448,
#  97,
#  623,
#  616,
#  288,
#  322,
#  72,
#  771,
#  61,
#  399,
#  926,
#  579,
#  836,
#  976,
#  49,
#  991,
#  536,
#  864,
#  283,
#  884,
#  930,
#  396,
#  25,
#  848,
#  255,
#  433,
#  710,
#  578,
#  491,
#  758,
#  417,
#  193,
#  215,
#  870,
#  261,
#  457,
#  126,
#  391,
#  784,
#  46,
#  762,
#  141,
#  769,
#  928,
#  220,
#  792,
#  260,
#  682,
#  44,
#  806,
#  919,
#  315,
#  812,
#  6,
#  209,
#  409,
#  581,
#  303,
#  740,
#  865,
#  822,
#  963,
#  729,
#  802,
#  856,
#  111,
#  387,
#  723,
#  340,
#  933,
#  728,
#  90,
#  997,
#  563,
#  764,
#  969,
#  73,
#  635,
#  922,
#  847,
#  539,
#  202,
#  960,
#  605,
#  217,
#  379,
#  435,
#  436,
#  957,
#  551,
#  178,
#  52,
#  971,
#  685,
#  515,
#  332,
#  566,
#  7,
#  68,
#  510,
#  618,
#  412,
#  421,
#  431,
#  299,
#  620,
#  877,
#  981,
#  540,
#  106,
#  757,
#  281,
#  810,
#  114,
#  559,
#  889,
#  177,
#  799,
#  292,
#  405,
#  43,
#  155,
#  736,
#  760,
#  943,
#  555,
#  139,
#  667,
#  98,
#  234,
#  669,
#  397,
#  447,
#  481,
#  756,
#  455,
#  626,
#  548,
#  196,
#  625,
#  866,
#  62,
#  372,
#  850,
#  569,
#  416,
#  553,
#  350,
#  989,
#  301,
#  93,
#  250,
#  321,
#  660,
#  596,
#  395,
#  77,
#  174,
#  814,
#  150,
#  541,
#  611,
#  122,
#  107,
#  959,
#  347,
#  430,
#  198,
#  876,
#  70,
#  378,
#  805,
#  942,
#  692,
#  239,
#  982,
#  145,
#  50]

# %%
from tqdm.auto import tqdm

target = np.log1p(train_y)
lgbm_seeds = [700, 560, 586, 542, 80]

SEED_scores = []
SEED_models = []

for SEED in tqdm(lgbm_seeds):
    print(f"{SEED}시드 시작")
    cv = KFold(n_splits=5, shuffle=True, random_state=SEED)
    scores = []
    models = []
    for tri , vai in cv.split(train_x): # k fold 앙상블
        # 학습 데이터
        x_train = train_x.iloc[tri]
        y_train = target.iloc[tri]

        # 검증 데이터
        x_valid = train_x.iloc[vai]
        y_valid = target.iloc[vai]

        lgbm_model = LGBMRegressor(**lgbm_best_params, random_state=SEED)
        lgbm_model.fit(x_train, y_train)
        pred = lgbm_model.predict(x_valid)
        score = rmsle(y_valid,pred)
        scores.append(score)
        models.append(lgbm_model) # 폴드별 학습된 모델 객체 담기

    SEED_scores.append(np.mean(scores))
    SEED_models.append(models)
    print(f"{SEED}번 시드 : {np.mean(scores)}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024244 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1343
# [LightGBM] [Info] Number of data points in the train set: 127168, number of used features: 38
# [LightGBM] [Info] Start training from score 1.647058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# 700번 시드 : 0.15797326377242668
# 560시드 시작
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064789 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1342
# [LightGBM] [Info] Number of data points in the train set: 127167, number of used features: 38
# [LightGBM] [Info] Start training from score 1.647470
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014451 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1344
# [LightGBM] [Info] Number of data points in the train set: 127167, number of used features: 38
# [LightGBM] [Info] Start training from score 1.647147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# 80번 시드 : 0.15797226119295735

# %%
SEED_scores

[0.1579732637724267,
 0.15793352241359326,
 0.15797246512114613,
 0.1579627631566401,
 0.15797226119295738]
# Out:
# [0.1579732637724267,
#  0.15793352241359326,
#  0.15797246512114613,
#  0.1579627631566401,
#  0.15797226119295738]

# %%
SEED_models # 25개의 모델
# Out:
# [[LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=700),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=700),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=700),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=700),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=700)],
#  [LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=560),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=560),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=560),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=560),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=560)],
#  [LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=586),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=586),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=586),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=586),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=586)],
#  [LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=542),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=542),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=542),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=542),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=542)],
#  [LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=80),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=80),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=80),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=80),
#   LGBMRegressor(bagging_fraction=0.17429104930042236,
#                 feature_fraction=0.8545377839510566, lambda_l1=6.529596581208154,
#                 lambda_l2=8.837614837937567, learning_rate=0.011407608181541297,
#                 max_depth=6, min_child_samples=59, n_estimators=1178,
#                 num_leaves=30, random_state=80)]]

# %%
from scipy.stats.mstats import gmean


seed_pred = []
for idx, seed in tqdm(enumerate(lgbm_seeds)):
    pred_list=[]
    for model in tqdm(SEED_models[idx]):
        pred = model.predict(test_x)
        pred = np.expm1(pred)
        pred_list.append(pred)
    pred_mean = gmean(pred_list)
    seed_pred.append(pred_mean)


# from scipy.stats.mstats import gmean

# seed_list = [7, 24, 25, 41, 44]
# seed_pred = []
# for seed in tqdm(seed_list):
#     pred_list = []
#     for model in tqdm(SEED_models[seed]):
#         pred = model.predict(test_enc)
#         pred_list.append(pred)
#     pred_gmean = gmean(pred_list)
#     seed_pred.append(pred_gmean)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
#   0%|          | 0/5 [00:00<?, ?it/s]
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236
# [LightGBM] [Warning] feature_fraction is set=0.8545377839510566, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8545377839510566
# [LightGBM] [Warning] lambda_l2 is set=8.837614837937567, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.837614837937567
# [LightGBM] [Warning] lambda_l1 is set=6.529596581208154, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.529596581208154
# [LightGBM] [Warning] bagging_fraction is set=0.17429104930042236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17429104930042236

# %%
seed_pred
# Out:
# [array([4.15001824, 3.69463396, 4.35832344, ..., 3.73187365, 4.63359336,
#         4.59181424]),
#  array([4.13833694, 3.68755397, 4.39476612, ..., 3.69368105, 4.64542495,
#         4.60628926]),
#  array([4.20765846, 3.70267067, 4.36925411, ..., 3.74594397, 4.64487858,
#         4.60836989]),
#  array([4.19146145, 3.71118433, 4.33252631, ..., 3.72904659, 4.66725292,
#         4.6264275 ]),
#  array([4.19283669, 3.71331145, 4.40197577, ..., 3.70651346, 4.67257679,
#         4.60840938])]

# %%
lgbm_df = pd.DataFrame(seed_pred).transpose()
lgbm_df
# Out:
#        구  시간대  요일  사고유형     도로형태2  피해운전자 상해정도_sorted
# 0     남구    0   0  차대사람     교차로부근           2.000000
# 1     남구    0   0  차대사람  교차로횡단보도내           1.000000
# 2     남구    0   0  차대사람        기타           3.200000
# 3     남구    0   0  차대사람       주차장           2.000000
# 4     남구    0   0   차대차     교차로부근           2.500000
# ...   ..  ...  ..   ...       ...                ...
# 3775  중구    6   6   차대차        교량           2.000000
# 3776  중구    6   6   차대차     교차로부근           2.285714
# 3777  중구    6   6   차대차      교차로안           2.000000
# 3778  중구    6   6   차대차        기타           2.391304
# 3779  중구    6   6  차량단독     교차로부근                NaN
#
# [3780 rows x 6 columns]

# %%
lgbm_df.to_csv(f'{DATA_PATH}lgbm_df.csv', index=False)

# %% [markdown]
# - xgb 앙상블

# %%
[338, 67, 700, 878, 12, 527, 600, 893, 897, 51, 609, 794, 148, 492, 937, 586, 885, 311, 104, 859, 236, 756, 659, 304, 582, 714, 411, 796, 212, 265, 944, 834, 101, 978, 358, 592, 983, 280, 153, 171, 161, 490, 722, 15, 665, 833, 29, 936, 601, 587, 36, 9, 999, 930, 75, 639, 139, 493, 189, 651, 724, 238, 82, 705, 506, 780, 105, 572, 906, 479, 982, 625, 392, 892, 725, 135, 972, 52, 58, 39, 645, 691, 406, 193, 456, 84, 334, 844, 573, 954, 510, 607, 674, 924, 362, 385, 635, 654, 629, 881, 664, 310, 262, 256, 356, 207, 180, 504, 474, 261, 124, 472, 900, 660, 147, 412, 69, 377, 652, 63, 623, 967, 167, 491, 257, 331, 668, 17, 316, 160, 330, 190, 154, 736, 782, 342, 364, 778, 523, 807, 214, 344, 360, 634, 539, 840, 59, 230, 952, 260, 687, 679, 290, 868, 40, 235, 537, 694, 252, 494, 986, 155, 123, 119, 195, 476, 341, 822, 643, 823, 42, 199, 835, 239, 843, 277, 721, 448, 297, 742, 373, 984, 913, 85, 898, 93, 404, 581, 302, 774, 735, 110, 87, 446, 438, 137, 141, 284, 22, 684, 35, 200, 940, 473, 237, 322, 707, 384, 346, 767, 829, 55, 908, 563, 53, 74, 170, 5, 511, 615, 115, 922, 622, 447, 670, 715, 339, 751, 401, 846, 763, 612, 327, 567, 535, 636, 928, 191, 353, 121, 734, 442, 374, 650, 588, 716, 395, 471, 184, 887, 397, 268, 247, 279, 113, 444, 804, 405, 245, 403, 576, 968, 97, 597, 367, 808, 475, 830, 852, 27, 398, 272, 315, 26, 117, 841, 34, 99, 484, 558, 56, 267, 698, 726, 836, 495, 854, 449, 222, 477, 785, 697, 749, 732, 64, 853, 580, 291, 244, 880, 350, 524, 896, 441, 465, 0, 699, 372, 644, 453, 140, 419, 640, 312, 744, 642, 309, 263, 759, 437, 522, 910, 779, 348, 813, 156, 613, 917, 549, 995, 80, 871, 747, 512, 534, 413, 133, 533, 210, 966, 332, 100, 96, 761, 584, 79, 565, 872, 509, 324, 44, 220, 498, 585, 977, 904, 98, 855, 387, 370, 864, 528, 909, 879, 503, 753, 980, 489, 706, 914, 271, 953, 981, 626, 305, 890, 951, 209, 907, 987, 663, 870, 513, 915, 215, 547, 349, 765, 923, 250, 655, 793, 766, 500, 273, 620, 961, 764, 616, 216, 432, 423, 630, 168, 108, 194, 800, 710, 861, 467, 203, 974, 445, 224, 485, 340, 741, 293, 677, 496, 637, 956, 902, 120, 740, 969, 179, 355, 554, 389, 555, 617, 433, 733, 693, 927, 352, 418, 242, 88, 501, 488, 428, 776, 820, 526, 380, 569, 30, 801, 757, 545, 276, 943, 518, 671, 935, 646, 519, 249, 205, 146, 614, 172, 188, 258, 631, 178, 111, 181, 590, 882, 683, 717, 708, 738, 152, 599, 560, 343, 164, 797, 225, 248, 536, 720, 112, 695, 296, 460, 68, 905, 777, 114, 481, 301, 275, 544, 932, 41, 462, 335, 737, 19, 440, 486, 850, 970, 144, 826, 382, 508, 369, 368, 719, 162, 420, 452, 157, 583, 556, 38, 729, 201, 1, 106, 320, 912, 916, 516, 425, 949, 873, 176, 552, 602, 386, 550, 992, 289, 129, 185, 407, 529, 945, 464, 575, 606, 960, 648, 166, 595, 169, 561, 934, 889, 628, 994, 858, 122, 429, 234, 354, 94, 838, 443, 246, 946, 345, 938, 874, 232, 875, 487, 231, 49, 791, 755, 62, 223, 811, 790, 183, 895, 656, 371, 675, 142, 422, 997, 627, 213, 760, 965, 435, 579, 514, 270, 799, 126, 918, 11, 964, 666, 845, 328, 18, 103, 383, 243, 564, 3, 365, 259, 57, 894, 317, 605, 958, 24, 300, 287, 657, 134, 709, 71, 388, 532, 812, 182, 173, 308, 379, 357, 361, 394, 920, 866, 939, 993, 197, 16, 658, 806, 598, 814, 145, 869, 251, 857, 198, 266, 703, 713, 90, 578, 689, 314, 37, 798, 482, 363, 461, 926, 682, 282, 47, 955, 470, 884, 680, 295, 883, 848, 681, 867, 831, 130, 116, 499, 459, 557, 672, 208, 570, 427, 690, 568, 899, 72, 876, 517, 151, 274, 608, 802, 20, 478, 686, 696, 158, 303, 787, 424, 704, 842, 255, 434, 333, 468, 415, 43, 957, 23, 285, 860, 525, 828, 241, 430, 421, 396, 132, 803, 632, 390, 589, 366, 46, 553, 865, 851, 240, 229, 621, 971, 329, 809, 610, 118, 772, 758, 688, 771, 318, 788, 574, 998, 150, 264, 754, 8, 321, 990, 107, 431, 159, 543, 325, 25, 531, 542, 901, 95, 454, 163, 14, 218, 149, 375, 792, 933, 662, 92, 86, 633, 351, 463, 128, 187, 450, 228, 227, 61, 306, 849, 45, 619, 743, 789, 393, 483, 409, 816, 186, 337, 347, 810, 211, 647, 947, 131, 269, 286, 125, 783, 702, 507, 177, 21, 752, 175, 775, 288, 408, 336, 31, 773, 669, 359, 825, 959, 78, 653, 81, 77, 551, 723, 562, 618, 165, 313, 931, 502, 505, 254, 962, 596, 530, 298, 676, 624, 817, 410, 819, 28, 577, 649, 7, 929, 89, 48, 414, 827, 376, 2, 604, 83, 979, 638, 292, 217, 204, 996, 673, 591, 54, 4, 378, 711, 319, 769, 458, 73, 821, 786, 950, 417, 455, 832, 402, 641, 466, 13, 712, 294, 837, 299, 219, 685, 202, 571, 540, 221, 566, 948, 391, 863, 66, 727, 480, 416, 976, 942, 768, 226, 985, 323, 903, 206, 10, 136, 521, 541, 839, 32, 326, 891, 973, 381, 76, 283, 515, 439, 60, 678, 805, 667, 925, 143, 877, 824, 538, 138, 520, 102, 469, 911, 233, 593, 718, 603, 451, 281, 989, 750, 174, 856, 426, 730, 748, 784, 307, 399, 196, 497, 746, 921, 739, 594, 795, 559, 888, 548, 436, 253, 975, 963, 6, 815, 847, 278, 65, 701, 728, 770, 862, 731, 941, 70, 109, 661, 781, 127, 457, 33, 745, 762, 919, 192, 611, 886, 991, 692, 91, 400, 546, 818, 988, 50]

# [700, 560, 586, 542, 80, 190, 786, 267, 839, 221, 537, 353, 575, 104, 12, 561, 4, 916, 707, 21, 366, 130, 286, 101, 476, 226, 693, 297, 673, 203, 944, 64, 609, 75, 242, 167, 305, 352, 871, 0, 136, 697, 983, 440, 872, 402, 284, 819, 742, 584, 241, 74, 606, 462, 868, 88, 205, 978, 212, 675, 842, 84, 737, 557, 533, 778, 82, 680, 900, 121, 721, 820, 745, 377, 801, 690, 890, 743, 644, 2, 709, 473, 189, 547, 465, 932, 782, 230, 695, 279, 974, 747, 500, 9, 362, 413, 956, 719, 449, 414, 410, 456, 658, 924, 251, 661, 389, 724, 954, 269, 808, 204, 56, 308, 331, 861, 681, 527, 846, 906, 741, 273, 154, 349, 794, 780, 829, 243, 22, 291, 164, 403, 672, 445, 498, 468, 774, 793, 227, 244, 486, 354, 811, 55, 694, 564, 424, 665, 570, 705, 400, 821, 590, 513, 580, 950, 271, 312, 195, 268, 161, 119, 313, 763, 467, 109, 329, 289, 824, 41, 652, 333, 512, 157, 496, 338, 687, 1, 992, 826, 148, 637, 691, 996, 688, 8, 95, 543, 797, 980, 749, 117, 897, 100, 504, 883, 562, 53, 67, 597, 683, 601, 408, 708, 309, 859, 613, 364, 248, 910, 852, 206, 337, 134, 788, 3, 26, 654, 263, 999, 898, 123, 407, 804, 614, 341, 270, 881, 735, 854, 323, 765, 961, 507, 24, 208, 679, 632, 10, 830, 619, 168, 185, 127, 604, 45, 96, 832, 668, 236, 207, 914, 835, 633, 511, 655, 857, 129, 809, 785, 406, 686, 739, 380, 32, 392, 452, 639, 873, 494, 225, 131, 153, 891, 796, 17, 588, 594, 200, 659, 143, 524, 63, 47, 213, 703, 522, 438, 607, 893, 103, 546, 696, 180, 946, 172, 568, 844, 461, 657, 939, 495, 361, 874, 753, 955, 249, 184, 554, 718, 20, 953, 958, 343, 689, 146, 731, 803, 716, 427, 882, 934, 752, 388, 738, 825, 429, 663, 152, 278, 518, 565, 636, 904, 30, 592, 298, 666, 887, 977, 156, 368, 58, 39, 903, 381, 630, 479, 558, 85, 78, 509, 768, 31, 105, 257, 275, 754, 15, 335, 787, 927, 949, 296, 426, 219, 194, 118, 319, 698, 845, 165, 641, 351, 162, 192, 940, 585, 128, 166, 576, 304, 987, 772, 751, 375, 608, 223, 795, 348, 766, 191, 965, 282, 401, 602, 149, 629, 137, 124, 69, 583, 235, 33, 621, 451, 358, 998, 761, 34, 133, 272, 888, 853, 538, 593, 422, 624, 722, 201, 938, 869, 610, 937, 466, 214, 404, 469, 798, 662, 833, 984, 489, 508, 913, 671, 464, 38, 577, 600, 627, 110, 497, 529, 446, 390, 425, 574, 183, 176, 544, 376, 28, 65, 638, 170, 140, 779, 48, 993, 589, 135, 862, 66, 316, 506, 158, 653, 968, 642, 783, 411, 173, 677, 453, 306, 572, 918, 595, 29, 837, 730, 911, 493, 715, 523, 471, 748, 781, 647, 218, 651, 247, 892, 860, 16, 643, 310, 750, 346, 345, 899, 567, 463, 199, 775, 42, 907, 634, 770, 746, 670, 552, 14, 896, 211, 676, 367, 902, 726, 385, 5, 915, 334, 935, 474, 439, 320, 262, 648, 503, 923, 929, 266, 678, 187, 443, 838, 941, 294, 371, 909, 327, 488, 19, 355, 280, 336, 40, 975, 382, 514, 339, 264, 936, 428, 256, 617, 240, 650, 962, 800, 713, 475, 484, 59, 370, 314, 36, 587, 102, 791, 640, 556, 843, 125, 92, 945, 813, 415, 501, 325, 712, 342, 113, 776, 849, 87, 920, 994, 224, 307, 549, 480, 423, 328, 947, 528, 285, 841, 393, 951, 858, 531, 311, 147, 967, 115, 37, 535, 492, 300, 598, 254, 656, 237, 591, 720, 79, 23, 815, 485, 210, 197, 13, 880, 827, 434, 35, 169, 863, 369, 790, 108, 816, 442, 441, 112, 437, 972, 419, 460, 238, 179, 477, 432, 931, 550, 701, 649, 948, 894, 295, 823, 732, 175, 699, 188, 132, 344, 925, 246, 986, 525, 81, 714, 840, 966, 265, 216, 57, 160, 867, 612, 27, 76, 885, 886, 138, 875, 878, 181, 470, 99, 895, 91, 622, 628, 472, 499, 60, 420, 979, 985, 163, 521, 398, 482, 603, 520, 317, 532, 454, 71, 646, 318, 384, 487, 704, 773, 917, 365, 142, 530, 545, 879, 144, 912, 851, 759, 807, 828, 245, 526, 458, 232, 855, 222, 94, 908, 394, 767, 151, 817, 89, 287, 357, 777, 330, 18, 483, 51, 921, 582, 631, 664, 517, 274, 252, 995, 901, 171, 186, 717, 727, 478, 277, 905, 83, 293, 519, 834, 228, 120, 276, 444, 674, 534, 11, 734, 386, 259, 711, 86, 573, 324, 490, 725, 645, 326, 116, 374, 964, 831, 599, 383, 789, 54, 229, 182, 233, 258, 363, 302, 459, 505, 952, 290, 356, 360, 253, 373, 702, 615, 988, 571, 755, 970, 973, 418, 159, 990, 516, 684, 231, 818, 733, 706, 744, 502, 359, 450, 448, 97, 623, 616, 288, 322, 72, 771, 61, 399, 926, 579, 836, 976, 49, 991, 536, 864, 283, 884, 930, 396, 25, 848, 255, 433, 710, 578, 491, 758, 417, 193, 215, 870, 261, 457, 126, 391, 784, 46, 762, 141, 769, 928, 220, 792, 260, 682, 44, 806, 919, 315, 812, 6, 209, 409, 581, 303, 740, 865, 822, 963, 729, 802, 856, 111, 387, 723, 340, 933, 728, 90, 997, 563, 764, 969, 73, 635, 922, 847, 539, 202, 960, 605, 217, 379, 435, 436, 957, 551, 178, 52, 971, 685, 515, 332, 566, 7, 68, 510, 618, 412, 421, 431, 299, 620, 877, 981, 540, 106, 757, 281, 810, 114, 559, 889, 177, 799, 292, 405, 43, 155, 736, 760, 943, 555, 139, 667, 98, 234, 669, 397, 447, 481, 756, 455, 626, 548, 196, 625, 866, 62, 372, 850, 569, 416, 553, 350, 989, 301, 93, 250, 321, 660, 596, 395, 77, 174, 814, 150, 541, 611, 122, 107, 959, 347, 430, 198, 876, 70, 378, 805, 942, 692, 239, 982, 145, 50]
# Out:
# [338,
#  67,
#  700,
#  878,
#  12,
#  527,
#  600,
#  893,
#  897,
#  51,
#  609,
#  794,
#  148,
#  492,
#  937,
#  586,
#  885,
#  311,
#  104,
#  859,
#  236,
#  756,
#  659,
#  304,
#  582,
#  714,
#  411,
#  796,
#  212,
#  265,
#  944,
#  834,
#  101,
#  978,
#  358,
#  592,
#  983,
#  280,
#  153,
#  171,
#  161,
#  490,
#  722,
#  15,
#  665,
#  833,
#  29,
#  936,
#  601,
#  587,
#  36,
#  9,
#  999,
#  930,
#  75,
#  639,
#  139,
#  493,
#  189,
#  651,
#  724,
#  238,
#  82,
#  705,
#  506,
#  780,
#  105,
#  572,
#  906,
#  479,
#  982,
#  625,
#  392,
#  892,
#  725,
#  135,
#  972,
#  52,
#  58,
#  39,
#  645,
#  691,
#  406,
#  193,
#  456,
#  84,
#  334,
#  844,
#  573,
#  954,
#  510,
#  607,
#  674,
#  924,
#  362,
#  385,
#  635,
#  654,
#  629,
#  881,
#  664,
#  310,
#  262,
#  256,
#  356,
#  207,
#  180,
#  504,
#  474,
#  261,
#  124,
#  472,
#  900,
#  660,
#  147,
#  412,
#  69,
#  377,
#  652,
#  63,
#  623,
#  967,
#  167,
#  491,
#  257,
#  331,
#  668,
#  17,
#  316,
#  160,
#  330,
#  190,
#  154,
#  736,
#  782,
#  342,
#  364,
#  778,
#  523,
#  807,
#  214,
#  344,
#  360,
#  634,
#  539,
#  840,
#  59,
#  230,
#  952,
#  260,
#  687,
#  679,
#  290,
#  868,
#  40,
#  235,
#  537,
#  694,
#  252,
#  494,
#  986,
#  155,
#  123,
#  119,
#  195,
#  476,
#  341,
#  822,
#  643,
#  823,
#  42,
#  199,
#  835,
#  239,
#  843,
#  277,
#  721,
#  448,
#  297,
#  742,
#  373,
#  984,
#  913,
#  85,
#  898,
#  93,
#  404,
#  581,
#  302,
#  774,
#  735,
#  110,
#  87,
#  446,
#  438,
#  137,
#  141,
#  284,
#  22,
#  684,
#  35,
#  200,
#  940,
#  473,
#  237,
#  322,
#  707,
#  384,
#  346,
#  767,
#  829,
#  55,
#  908,
#  563,
#  53,
#  74,
#  170,
#  5,
#  511,
#  615,
#  115,
#  922,
#  622,
#  447,
#  670,
#  715,
#  339,
#  751,
#  401,
#  846,
#  763,
#  612,
#  327,
#  567,
#  535,
#  636,
#  928,
#  191,
#  353,
#  121,
#  734,
#  442,
#  374,
#  650,
#  588,
#  716,
#  395,
#  471,
#  184,
#  887,
#  397,
#  268,
#  247,
#  279,
#  113,
#  444,
#  804,
#  405,
#  245,
#  403,
#  576,
#  968,
#  97,
#  597,
#  367,
#  808,
#  475,
#  830,
#  852,
#  27,
#  398,
#  272,
#  315,
#  26,
#  117,
#  841,
#  34,
#  99,
#  484,
#  558,
#  56,
#  267,
#  698,
#  726,
#  836,
#  495,
#  854,
#  449,
#  222,
#  477,
#  785,
#  697,
#  749,
#  732,
#  64,
#  853,
#  580,
#  291,
#  244,
#  880,
#  350,
#  524,
#  896,
#  441,
#  465,
#  0,
#  699,
#  372,
#  644,
#  453,
#  140,
#  419,
#  640,
#  312,
#  744,
#  642,
#  309,
#  263,
#  759,
#  437,
#  522,
#  910,
#  779,
#  348,
#  813,
#  156,
#  613,
#  917,
#  549,
#  995,
#  80,
#  871,
#  747,
#  512,
#  534,
#  413,
#  133,
#  533,
#  210,
#  966,
#  332,
#  100,
#  96,
#  761,
#  584,
#  79,
#  565,
#  872,
#  509,
#  324,
#  44,
#  220,
#  498,
#  585,
#  977,
#  904,
#  98,
#  855,
#  387,
#  370,
#  864,
#  528,
#  909,
#  879,
#  503,
#  753,
#  980,
#  489,
#  706,
#  914,
#  271,
#  953,
#  981,
#  626,
#  305,
#  890,
#  951,
#  209,
#  907,
#  987,
#  663,
#  870,
#  513,
#  915,
#  215,
#  547,
#  349,
#  765,
#  923,
#  250,
#  655,
#  793,
#  766,
#  500,
#  273,
#  620,
#  961,
#  764,
#  616,
#  216,
#  432,
#  423,
#  630,
#  168,
#  108,
#  194,
#  800,
#  710,
#  861,
#  467,
#  203,
#  974,
#  445,
#  224,
#  485,
#  340,
#  741,
#  293,
#  677,
#  496,
#  637,
#  956,
#  902,
#  120,
#  740,
#  969,
#  179,
#  355,
#  554,
#  389,
#  555,
#  617,
#  433,
#  733,
#  693,
#  927,
#  352,
#  418,
#  242,
#  88,
#  501,
#  488,
#  428,
#  776,
#  820,
#  526,
#  380,
#  569,
#  30,
#  801,
#  757,
#  545,
#  276,
#  943,
#  518,
#  671,
#  935,
#  646,
#  519,
#  249,
#  205,
#  146,
#  614,
#  172,
#  188,
#  258,
#  631,
#  178,
#  111,
#  181,
#  590,
#  882,
#  683,
#  717,
#  708,
#  738,
#  152,
#  599,
#  560,
#  343,
#  164,
#  797,
#  225,
#  248,
#  536,
#  720,
#  112,
#  695,
#  296,
#  460,
#  68,
#  905,
#  777,
#  114,
#  481,
#  301,
#  275,
#  544,
#  932,
#  41,
#  462,
#  335,
#  737,
#  19,
#  440,
#  486,
#  850,
#  970,
#  144,
#  826,
#  382,
#  508,
#  369,
#  368,
#  719,
#  162,
#  420,
#  452,
#  157,
#  583,
#  556,
#  38,
#  729,
#  201,
#  1,
#  106,
#  320,
#  912,
#  916,
#  516,
#  425,
#  949,
#  873,
#  176,
#  552,
#  602,
#  386,
#  550,
#  992,
#  289,
#  129,
#  185,
#  407,
#  529,
#  945,
#  464,
#  575,
#  606,
#  960,
#  648,
#  166,
#  595,
#  169,
#  561,
#  934,
#  889,
#  628,
#  994,
#  858,
#  122,
#  429,
#  234,
#  354,
#  94,
#  838,
#  443,
#  246,
#  946,
#  345,
#  938,
#  874,
#  232,
#  875,
#  487,
#  231,
#  49,
#  791,
#  755,
#  62,
#  223,
#  811,
#  790,
#  183,
#  895,
#  656,
#  371,
#  675,
#  142,
#  422,
#  997,
#  627,
#  213,
#  760,
#  965,
#  435,
#  579,
#  514,
#  270,
#  799,
#  126,
#  918,
#  11,
#  964,
#  666,
#  845,
#  328,
#  18,
#  103,
#  383,
#  243,
#  564,
#  3,
#  365,
#  259,
#  57,
#  894,
#  317,
#  605,
#  958,
#  24,
#  300,
#  287,
#  657,
#  134,
#  709,
#  71,
#  388,
#  532,
#  812,
#  182,
#  173,
#  308,
#  379,
#  357,
#  361,
#  394,
#  920,
#  866,
#  939,
#  993,
#  197,
#  16,
#  658,
#  806,
#  598,
#  814,
#  145,
#  869,
#  251,
#  857,
#  198,
#  266,
#  703,
#  713,
#  90,
#  578,
#  689,
#  314,
#  37,
#  798,
#  482,
#  363,
#  461,
#  926,
#  682,
#  282,
#  47,
#  955,
#  470,
#  884,
#  680,
#  295,
#  883,
#  848,
#  681,
#  867,
#  831,
#  130,
#  116,
#  499,
#  459,
#  557,
#  672,
#  208,
#  570,
#  427,
#  690,
#  568,
#  899,
#  72,
#  876,
#  517,
#  151,
#  274,
#  608,
#  802,
#  20,
#  478,
#  686,
#  696,
#  158,
#  303,
#  787,
#  424,
#  704,
#  842,
#  255,
#  434,
#  333,
#  468,
#  415,
#  43,
#  957,
#  23,
#  285,
#  860,
#  525,
#  828,
#  241,
#  430,
#  421,
#  396,
#  132,
#  803,
#  632,
#  390,
#  589,
#  366,
#  46,
#  553,
#  865,
#  851,
#  240,
#  229,
#  621,
#  971,
#  329,
#  809,
#  610,
#  118,
#  772,
#  758,
#  688,
#  771,
#  318,
#  788,
#  574,
#  998,
#  150,
#  264,
#  754,
#  8,
#  321,
#  990,
#  107,
#  431,
#  159,
#  543,
#  325,
#  25,
#  531,
#  542,
#  901,
#  95,
#  454,
#  163,
#  14,
#  218,
#  149,
#  375,
#  792,
#  933,
#  662,
#  92,
#  86,
#  633,
#  351,
#  463,
#  128,
#  187,
#  450,
#  228,
#  227,
#  61,
#  306,
#  849,
#  45,
#  619,
#  743,
#  789,
#  393,
#  483,
#  409,
#  816,
#  186,
#  337,
#  347,
#  810,
#  211,
#  647,
#  947,
#  131,
#  269,
#  286,
#  125,
#  783,
#  702,
#  507,
#  177,
#  21,
#  752,
#  175,
#  775,
#  288,
#  408,
#  336,
#  31,
#  773,
#  669,
#  359,
#  825,
#  959,
#  78,
#  653,
#  81,
#  77,
#  551,
#  723,
#  562,
#  618,
#  165,
#  313,
#  931,
#  502,
#  505,
#  254,
#  962,
#  596,
#  530,
#  298,
#  676,
#  624,
#  817,
#  410,
#  819,
#  28,
#  577,
#  649,
#  7,
#  929,
#  89,
#  48,
#  414,
#  827,
#  376,
#  2,
#  604,
#  83,
#  979,
#  638,
#  292,
#  217,
#  204,
#  996,
#  673,
#  591,
#  54,
#  4,
#  378,
#  711,
#  319,
#  769,
#  458,
#  73,
#  821,
#  786,
#  950,
#  417,
#  455,
#  832,
#  402,
#  641,
#  466,
#  13,
#  712,
#  294,
#  837,
#  299,
#  219,
#  685,
#  202,
#  571,
#  540,
#  221,
#  566,
#  948,
#  391,
#  863,
#  66,
#  727,
#  480,
#  416,
#  976,
#  942,
#  768,
#  226,
#  985,
#  323,
#  903,
#  206,
#  10,
#  136,
#  521,
#  541,
#  839,
#  32,
#  326,
#  891,
#  973,
#  381,
#  76,
#  283,
#  515,
#  439,
#  60,
#  678,
#  805,
#  667,
#  925,
#  143,
#  877,
#  824,
#  538,
#  138,
#  520,
#  102,
#  469,
#  911,
#  233,
#  593,
#  718,
#  603,
#  451,
#  281,
#  989,
#  750,
#  174,
#  856,
#  426,
#  730,
#  748,
#  784,
#  307,
#  399,
#  196,
#  497,
#  746,
#  921,
#  739,
#  594,
#  795,
#  559,
#  888,
#  548,
#  436,
#  253,
#  975,
#  963,
#  6,
#  815,
#  847,
#  278,
#  65,
#  701,
#  728,
#  770,
#  862,
#  731,
#  941,
#  70,
#  109,
#  661,
#  781,
#  127,
#  457,
#  33,
#  745,
#  762,
#  919,
#  192,
#  611,
#  886,
#  991,
#  692,
#  91,
#  400,
#  546,
#  818,
#  988,
#  50]

# %%
from tqdm.auto import tqdm

target = train_y
xgb_seeds = [338, 67, 700, 878, 12]

SEED_scores = []
SEED_models = []

for SEED in tqdm(xgb_seeds):
    print(f"{SEED}시드 시작")
    cv = KFold(n_splits=5, shuffle=True, random_state=SEED)
    scores = []
    models = []
    for tri , vai in cv.split(train_x): # k fold 앙상블
        # 학습 데이터
        x_train = train_x.iloc[tri]
        y_train = target.iloc[tri]

        # 검증 데이터
        x_valid = train_x.iloc[vai]
        y_valid = target.iloc[vai]

        xgb_model = XGBRegressor(objective='reg:squaredlogerror', eval_metric='rmsle', **xgb_best_params, random_state=SEED)
        xgb_model.fit(x_train, y_train)
        pred = xgb_model.predict(x_valid)
        score = rmsle(y_valid,pred)
        scores.append(score)
        models.append(xgb_model) # 폴드별 학습된 모델 객체 담기

    SEED_scores.append(np.mean(scores))
    SEED_models.append(models)
    print(f"{SEED}번 시드 : {np.mean(scores)}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 338시드 시작
# 338번 시드 : 0.41811254047080093
# 67시드 시작
# 67번 시드 : 0.4180591028587492
# 700시드 시작
# 700번 시드 : 0.4180795332745574
# 878시드 시작
# 878번 시드 : 0.41804175736667526
# 12시드 시작
# 12번 시드 : 0.4181083131179202

# %%
seed_pred

# %%
SEED_models
# Out:
# [[XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...)],
#  [XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...)],
#  [XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...)],
#  [XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...)],
#  [XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...),
#   XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.8429061023478192, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric='rmsle', feature_types=None, gamma=0.7071727358928532,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.024010747652112696,
#                max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=24, max_leaves=None,
#                min_child_weight=2, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=3241, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squaredlogerror', ...)]]

# %%
# from scipy.stats.mstats import gmean


# seed_pred = []
# for idx, seed in tqdm(enumerate(lgbm_seeds)):
#     pred_list=[]
#     for model in tqdm(SEED_models[idx]):
#         pred = model.predict(test_x)
#         pred = np.expm1(pred)
#         pred_list.append(pred)
#     pred_mean = gmean(pred_list)
#     seed_pred.append(pred_mean)


from scipy.stats.mstats import gmean

seed_pred = []
for idx, seed in tqdm(enumerate(xgb_seeds)):
    pred_list=[]
    for model in tqdm(SEED_models[idx]):
        pred = model.predict(test_x)
        # pred = np.expm1(pred)
        pred_list.append(pred)
    pred_mean = gmean(pred_list)
    seed_pred.append(pred_mean)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
xgb_df = pd.DataFrame(seed_pred).transpose()
xgb_df
# Out:
#               0         1         2         3         4
# 0      4.128914  4.204660  4.201684  4.162585  4.156024
# 1      3.668110  3.647670  3.720807  3.660049  3.718945
# 2      4.358341  4.356406  4.375614  4.383730  4.366761
# 3      4.092301  4.068682  4.095982  4.021044  4.107259
# 4      4.545054  4.582445  4.542928  4.571039  4.521232
# ...         ...       ...       ...       ...       ...
# 10958  5.771307  5.758663  5.748721  5.832650  5.771062
# 10959  3.673392  3.670820  3.709404  3.686374  3.706645
# 10960  3.731966  3.730936  3.764326  3.737476  3.786582
# 10961  4.664433  4.632857  4.685436  4.645179  4.618321
# 10962  4.523620  4.559039  4.520933  4.529456  4.499360
#
# [10963 rows x 5 columns]

# %%
xgb_df.to_csv(f'{DATA_PATH}xgb_df.csv', index=False)

# %% [markdown]
# - cat seed확인

# %%
from tqdm.auto import tqdm

target = np.log1p(train_y)
cat_seeds = [700, 560, 586, 542, 80]

SEED_scores = []
SEED_models = []

for SEED in tqdm(cat_seeds):
    print(f"{SEED}시드 시작")
    cv = KFold(n_splits=5, shuffle=True, random_state=SEED)
    scores = []
    models = []
    for tri , vai in cv.split(train_x): # k fold 앙상블
        # 학습 데이터
        x_train = train_x.iloc[tri]
        y_train = target.iloc[tri]

        # 검증 데이터
        x_valid = train_x.iloc[vai]
        y_valid = target.iloc[vai]

        cat_model = CatBoostRegressor(**cat_best_params, random_state=SEED)
        cat_model.fit(x_train, y_train)
        pred = cat_model.predict(x_valid)
        score = rmsle(y_valid,pred)
        scores.append(score)
        models.append(cat_model) # 폴드별 학습된 모델 객체 담기

    SEED_scores.append(np.mean(scores))
    SEED_models.append(models)
    print(f"{SEED}번 시드 : {np.mean(scores)}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 896:	learn: 0.4117687	total: 23.6s	remaining: 7.42s
# 897:	learn: 0.4117621	total: 23.6s	remaining: 7.39s
# 898:	learn: 0.4117566	total: 23.6s	remaining: 7.36s
# 899:	learn: 0.4117496	total: 23.7s	remaining: 7.33s
# 900:	learn: 0.4117428	total: 23.7s	remaining: 7.31s
# 901:	learn: 0.4117362	total: 23.7s	remaining: 7.28s
# 902:	learn: 0.4117322	total: 23.7s	remaining: 7.25s
# 903:	learn: 0.4117282	total: 23.7s	remaining: 7.22s
# 904:	learn: 0.4117167	total: 23.8s	remaining: 7.19s
# 905:	learn: 0.4117071	total: 23.8s	remaining: 7.17s
# 906:	learn: 0.4117015	total: 23.8s	remaining: 7.14s
# 907:	learn: 0.4116944	total: 23.8s	remaining: 7.11s
# 908:	learn: 0.4116869	total: 23.8s	remaining: 7.08s
# 909:	learn: 0.4116797	total: 23.9s	remaining: 7.05s
# 910:	learn: 0.4116722	total: 23.9s	remaining: 7.02s
# 911:	learn: 0.4116624	total: 23.9s	remaining: 7s
# 912:	learn: 0.4116556	total: 23.9s	remaining: 6.97s
# 913:	learn: 0.4116473	total: 23.9s	remaining: 6.94s
# 914:	learn: 0.4116437	total: 24s	remaining: 6.91s
# 915:	learn: 0.4116353	total: 24s	remaining: 6.89s
# 916:	learn: 0.4116274	total: 24s	remaining: 6.86s
# 917:	learn: 0.4116214	total: 24s	remaining: 6.83s
# 918:	learn: 0.4116141	total: 24s	remaining: 6.8s
# 919:	learn: 0.4116081	total: 24.1s	remaining: 6.77s
# 920:	learn: 0.4116011	total: 24.1s	remaining: 6.75s
# 921:	learn: 0.4115945	total: 24.1s	remaining: 6.72s
# 922:	learn: 0.4115865	total: 24.1s	remaining: 6.69s
# 923:	learn: 0.4115798	total: 24.1s	remaining: 6.66s
# 924:	learn: 0.4115742	total: 24.2s	remaining: 6.63s
# 925:	learn: 0.4115676	total: 24.2s	remaining: 6.61s
# 926:	learn: 0.4115598	total: 24.2s	remaining: 6.58s
# 927:	learn: 0.4115497	total: 24.2s	remaining: 6.55s
# 928:	learn: 0.4115461	total: 24.2s	remaining: 6.52s
# 929:	learn: 0.4115381	total: 24.3s	remaining: 6.5s
# 930:	learn: 0.4115325	total: 24.3s	remaining: 6.47s
# 931:	learn: 0.4115251	total: 24.3s	remaining: 6.44s
# 932:	learn: 0.4115174	total: 24.3s	remaining: 6.41s
# 933:	learn: 0.4115104	total: 24.3s	remaining: 6.38s
# 934:	learn: 0.4115057	total: 24.4s	remaining: 6.36s
# 935:	learn: 0.4114997	total: 24.4s	remaining: 6.33s
# 936:	learn: 0.4114901	total: 24.4s	remaining: 6.3s
# 937:	learn: 0.4114834	total: 24.4s	remaining: 6.28s
# 938:	learn: 0.4114759	total: 24.4s	remaining: 6.25s
# 939:	learn: 0.4114682	total: 24.5s	remaining: 6.22s
# 940:	learn: 0.4114617	total: 24.5s	remaining: 6.2s
# 941:	learn: 0.4114541	total: 24.5s	remaining: 6.17s
# 942:	learn: 0.4114442	total: 24.5s	remaining: 6.14s
# 943:	learn: 0.4114352	total: 24.6s	remaining: 6.11s
# 944:	learn: 0.4114279	total: 24.6s	remaining: 6.08s
# 945:	learn: 0.4114208	total: 24.6s	remaining: 6.06s
# 946:	learn: 0.4114150	total: 24.6s	remaining: 6.03s
# 947:	learn: 0.4114095	total: 24.6s	remaining: 6s
# 948:	learn: 0.4114050	total: 24.7s	remaining: 5.98s
# 949:	learn: 0.4113949	total: 24.7s	remaining: 5.95s
# 950:	learn: 0.4113871	total: 24.7s	remaining: 5.92s
# 951:	learn: 0.4113772	total: 24.7s	remaining: 5.89s
# 952:	learn: 0.4113686	total: 24.7s	remaining: 5.87s
# 953:	learn: 0.4113599	total: 24.8s	remaining: 5.84s
# 954:	learn: 0.4113524	total: 24.8s	remaining: 5.81s
# 955:	learn: 0.4113450	total: 24.8s	remaining: 5.78s
# 956:	learn: 0.4113392	total: 24.8s	remaining: 5.75s
# 957:	learn: 0.4113342	total: 24.8s	remaining: 5.73s
# 958:	learn: 0.4113274	total: 24.9s	remaining: 5.7s
# 959:	learn: 0.4113184	total: 24.9s	remaining: 5.68s
# 960:	learn: 0.4113091	total: 24.9s	remaining: 5.65s
# 961:	learn: 0.4112985	total: 24.9s	remaining: 5.62s
# 962:	learn: 0.4112889	total: 24.9s	remaining: 5.6s
# 963:	learn: 0.4112810	total: 25s	remaining: 5.57s
# 964:	learn: 0.4112727	total: 25s	remaining: 5.54s
# 965:	learn: 0.4112656	total: 25s	remaining: 5.51s
# 966:	learn: 0.4112581	total: 25s	remaining: 5.49s
# 967:	learn: 0.4112506	total: 25s	remaining: 5.46s
# 968:	learn: 0.4112476	total: 25.1s	remaining: 5.43s
# 969:	learn: 0.4112382	total: 25.1s	remaining: 5.41s
# 970:	learn: 0.4112293	total: 25.1s	remaining: 5.38s
# 971:	learn: 0.4112229	total: 25.1s	remaining: 5.35s
# 972:	learn: 0.4112165	total: 25.1s	remaining: 5.32s
# 973:	learn: 0.4112103	total: 25.2s	remaining: 5.29s
# 974:	learn: 0.4112049	total: 25.2s	remaining: 5.27s
# 975:	learn: 0.4112000	total: 25.2s	remaining: 5.24s
# 976:	learn: 0.4111909	total: 25.2s	remaining: 5.21s
# 977:	learn: 0.4111837	total: 25.2s	remaining: 5.19s
# 978:	learn: 0.4111799	total: 25.3s	remaining: 5.16s
# 979:	learn: 0.4111730	total: 25.3s	remaining: 5.13s
# 980:	learn: 0.4111655	total: 25.3s	remaining: 5.11s
# 981:	learn: 0.4111558	total: 25.3s	remaining: 5.08s
# 982:	learn: 0.4111491	total: 25.3s	remaining: 5.05s
# 983:	learn: 0.4111376	total: 25.4s	remaining: 5.03s
# 984:	learn: 0.4111318	total: 25.4s	remaining: 5s
# 985:	learn: 0.4111235	total: 25.4s	remaining: 4.97s
# 986:	learn: 0.4111158	total: 25.4s	remaining: 4.94s
# 987:	learn: 0.4111081	total: 25.4s	remaining: 4.92s
# 988:	learn: 0.4111034	total: 25.5s	remaining: 4.89s
# 989:	learn: 0.4110963	total: 25.5s	remaining: 4.86s
# 990:	learn: 0.4110906	total: 25.5s	remaining: 4.83s
# 991:	learn: 0.4110808	total: 25.5s	remaining: 4.81s
# 992:	learn: 0.4110729	total: 25.5s	remaining: 4.78s
# 993:	learn: 0.4110654	total: 25.5s	remaining: 4.75s
# 994:	learn: 0.4110599	total: 25.6s	remaining: 4.73s
# 995:	learn: 0.4110513	total: 25.6s	remaining: 4.7s
# 996:	learn: 0.4110443	total: 25.6s	remaining: 4.67s
# 997:	learn: 0.4110387	total: 25.6s	remaining: 4.65s
# 998:	learn: 0.4110328	total: 25.6s	remaining: 4.62s
# 999:	learn: 0.4110254	total: 25.7s	remaining: 4.59s
# 1000:	learn: 0.4110186	total: 25.7s	remaining: 4.57s
# 1001:	learn: 0.4110105	total: 25.7s	remaining: 4.54s
# 1002:	learn: 0.4110051	total: 25.7s	remaining: 4.51s
# 1003:	learn: 0.4109959	total: 25.8s	remaining: 4.49s
# 1004:	learn: 0.4109913	total: 25.8s	remaining: 4.46s
# 1005:	learn: 0.4109823	total: 25.8s	remaining: 4.43s
# 1006:	learn: 0.4109747	total: 25.8s	remaining: 4.41s
# 1007:	learn: 0.4109689	total: 25.8s	remaining: 4.38s
# 1008:	learn: 0.4109597	total: 25.8s	remaining: 4.35s
# 1009:	learn: 0.4109552	total: 25.9s	remaining: 4.33s
# 1010:	learn: 0.4109496	total: 25.9s	remaining: 4.3s
# 1011:	learn: 0.4109420	total: 25.9s	remaining: 4.27s
# 1012:	learn: 0.4109316	total: 25.9s	remaining: 4.25s
# 1013:	learn: 0.4109247	total: 25.9s	remaining: 4.22s
# 1014:	learn: 0.4109179	total: 26s	remaining: 4.2s
# 1015:	learn: 0.4109101	total: 26s	remaining: 4.17s
# 1016:	learn: 0.4109023	total: 26s	remaining: 4.14s
# 1017:	learn: 0.4108944	total: 26s	remaining: 4.12s
# 1018:	learn: 0.4108824	total: 26.1s	remaining: 4.09s
# 1019:	learn: 0.4108752	total: 26.1s	remaining: 4.06s
# 1020:	learn: 0.4108699	total: 26.1s	remaining: 4.04s
# 1021:	learn: 0.4108624	total: 26.1s	remaining: 4.01s
# 1022:	learn: 0.4108532	total: 26.1s	remaining: 3.98s
# 1023:	learn: 0.4108431	total: 26.2s	remaining: 3.96s
# 1024:	learn: 0.4108337	total: 26.2s	remaining: 3.93s
# 1025:	learn: 0.4108242	total: 26.2s	remaining: 3.91s
# 1026:	learn: 0.4108179	total: 26.2s	remaining: 3.88s
# 1027:	learn: 0.4108136	total: 26.2s	remaining: 3.85s
# 1028:	learn: 0.4108041	total: 26.3s	remaining: 3.83s
# 1029:	learn: 0.4107966	total: 26.3s	remaining: 3.8s
# 1030:	learn: 0.4107870	total: 26.3s	remaining: 3.78s
# 1031:	learn: 0.4107810	total: 26.3s	remaining: 3.75s
# 1032:	learn: 0.4107742	total: 26.3s	remaining: 3.72s
# 1033:	learn: 0.4107629	total: 26.4s	remaining: 3.7s
# 1034:	learn: 0.4107568	total: 26.4s	remaining: 3.67s
# 1035:	learn: 0.4107519	total: 26.4s	remaining: 3.65s
# 1036:	learn: 0.4107447	total: 26.4s	remaining: 3.62s
# 1037:	learn: 0.4107366	total: 26.4s	remaining: 3.59s
# 1038:	learn: 0.4107282	total: 26.5s	remaining: 3.57s
# 1039:	learn: 0.4107236	total: 26.5s	remaining: 3.54s
# 1040:	learn: 0.4107155	total: 26.5s	remaining: 3.51s
# 1041:	learn: 0.4107082	total: 26.5s	remaining: 3.49s
# 1042:	learn: 0.4107000	total: 26.5s	remaining: 3.46s
# 1043:	learn: 0.4106932	total: 26.6s	remaining: 3.43s
# 1044:	learn: 0.4106869	total: 26.6s	remaining: 3.41s
# 1045:	learn: 0.4106818	total: 26.6s	remaining: 3.38s
# 1046:	learn: 0.4106741	total: 26.6s	remaining: 3.36s
# 1047:	learn: 0.4106674	total: 26.6s	remaining: 3.33s
# 1048:	learn: 0.4106623	total: 26.7s	remaining: 3.3s
# 1049:	learn: 0.4106550	total: 26.7s	remaining: 3.28s
# 1050:	learn: 0.4106504	total: 26.7s	remaining: 3.25s
# 1051:	learn: 0.4106409	total: 26.7s	remaining: 3.23s
# 1052:	learn: 0.4106321	total: 26.7s	remaining: 3.2s
# 1053:	learn: 0.4106267	total: 26.8s	remaining: 3.17s
# 1054:	learn: 0.4106182	total: 26.8s	remaining: 3.15s
# 1055:	learn: 0.4106118	total: 26.8s	remaining: 3.12s
# 1056:	learn: 0.4106057	total: 26.8s	remaining: 3.1s
# 1057:	learn: 0.4105954	total: 26.8s	remaining: 3.07s
# 1058:	learn: 0.4105865	total: 26.9s	remaining: 3.04s
# 1059:	learn: 0.4105802	total: 26.9s	remaining: 3.02s
# 1060:	learn: 0.4105738	total: 26.9s	remaining: 2.99s
# 1061:	learn: 0.4105663	total: 26.9s	remaining: 2.97s
# 1062:	learn: 0.4105599	total: 26.9s	remaining: 2.94s
# 1063:	learn: 0.4105526	total: 27s	remaining: 2.91s
# 1064:	learn: 0.4105435	total: 27s	remaining: 2.89s
# 1065:	learn: 0.4105381	total: 27s	remaining: 2.86s
# 1066:	learn: 0.4105351	total: 27.1s	remaining: 2.84s
# 1067:	learn: 0.4105256	total: 27.1s	remaining: 2.81s
# 1068:	learn: 0.4105197	total: 27.1s	remaining: 2.79s
# 1069:	learn: 0.4105122	total: 27.1s	remaining: 2.76s
# 1070:	learn: 0.4105067	total: 27.1s	remaining: 2.73s
# 1071:	learn: 0.4104989	total: 27.1s	remaining: 2.71s
# 1072:	learn: 0.4104926	total: 27.2s	remaining: 2.68s
# 1073:	learn: 0.4104834	total: 27.2s	remaining: 2.66s
# 1074:	learn: 0.4104756	total: 27.2s	remaining: 2.63s
# 1075:	learn: 0.4104650	total: 27.2s	remaining: 2.61s
# 1076:	learn: 0.4104586	total: 27.3s	remaining: 2.58s
# 1077:	learn: 0.4104526	total: 27.3s	remaining: 2.56s
# 1078:	learn: 0.4104442	total: 27.3s	remaining: 2.53s
# 1079:	learn: 0.4104377	total: 27.3s	remaining: 2.5s
# 1080:	learn: 0.4104330	total: 27.3s	remaining: 2.48s
# 1081:	learn: 0.4104242	total: 27.4s	remaining: 2.45s
# 1082:	learn: 0.4104170	total: 27.4s	remaining: 2.43s
# 1083:	learn: 0.4104110	total: 27.4s	remaining: 2.4s
# 1084:	learn: 0.4104023	total: 27.4s	remaining: 2.38s
# 1085:	learn: 0.4103994	total: 27.4s	remaining: 2.35s
# 1086:	learn: 0.4103936	total: 27.5s	remaining: 2.32s
# 1087:	learn: 0.4103892	total: 27.5s	remaining: 2.3s
# 1088:	learn: 0.4103805	total: 27.5s	remaining: 2.27s
# 1089:	learn: 0.4103715	total: 27.5s	remaining: 2.25s
# 1090:	learn: 0.4103626	total: 27.5s	remaining: 2.22s
# 1091:	learn: 0.4103557	total: 27.6s	remaining: 2.2s
# 1092:	learn: 0.4103489	total: 27.6s	remaining: 2.17s
# 1093:	learn: 0.4103444	total: 27.6s	remaining: 2.14s
# 1094:	learn: 0.4103377	total: 27.6s	remaining: 2.12s
# 1095:	learn: 0.4103313	total: 27.6s	remaining: 2.09s
# 1096:	learn: 0.4103238	total: 27.7s	remaining: 2.07s
# 1097:	learn: 0.4103170	total: 27.7s	remaining: 2.04s
# 1098:	learn: 0.4103103	total: 27.7s	remaining: 2.02s
# 1099:	learn: 0.4103041	total: 27.7s	remaining: 1.99s
# 1100:	learn: 0.4102950	total: 27.8s	remaining: 1.97s
# 1101:	learn: 0.4102878	total: 27.8s	remaining: 1.94s
# 1102:	learn: 0.4102821	total: 27.8s	remaining: 1.91s
# 1103:	learn: 0.4102717	total: 27.8s	remaining: 1.89s
# 1104:	learn: 0.4102612	total: 27.8s	remaining: 1.86s
# 1105:	learn: 0.4102532	total: 27.8s	remaining: 1.84s
# 1106:	learn: 0.4102460	total: 27.9s	remaining: 1.81s
# 1107:	learn: 0.4102395	total: 27.9s	remaining: 1.79s
# 1108:	learn: 0.4102334	total: 27.9s	remaining: 1.76s
# 1109:	learn: 0.4102279	total: 27.9s	remaining: 1.74s
# 1110:	learn: 0.4102224	total: 28s	remaining: 1.71s
# 1111:	learn: 0.4102125	total: 28s	remaining: 1.69s
# 1112:	learn: 0.4102073	total: 28s	remaining: 1.66s
# 1113:	learn: 0.4101975	total: 28s	remaining: 1.63s
# 1114:	learn: 0.4101938	total: 28s	remaining: 1.61s
# 1115:	learn: 0.4101863	total: 28.1s	remaining: 1.58s
# 1116:	learn: 0.4101796	total: 28.1s	remaining: 1.56s
# 1117:	learn: 0.4101711	total: 28.1s	remaining: 1.53s
# 1118:	learn: 0.4101613	total: 28.1s	remaining: 1.51s
# 1119:	learn: 0.4101548	total: 28.1s	remaining: 1.48s
# 1120:	learn: 0.4101481	total: 28.2s	remaining: 1.46s
# 1121:	learn: 0.4101412	total: 28.2s	remaining: 1.43s
# 1122:	learn: 0.4101332	total: 28.2s	remaining: 1.41s
# 1123:	learn: 0.4101281	total: 28.2s	remaining: 1.38s
# 1124:	learn: 0.4101217	total: 28.2s	remaining: 1.35s
# 1125:	learn: 0.4101123	total: 28.2s	remaining: 1.33s
# 1126:	learn: 0.4101049	total: 28.3s	remaining: 1.3s
# 1127:	learn: 0.4100986	total: 28.3s	remaining: 1.28s
# 1128:	learn: 0.4100925	total: 28.3s	remaining: 1.25s
# 1129:	learn: 0.4100825	total: 28.4s	remaining: 1.23s
# 1130:	learn: 0.4100749	total: 28.4s	remaining: 1.2s
# 1131:	learn: 0.4100678	total: 28.4s	remaining: 1.18s
# 1132:	learn: 0.4100614	total: 28.4s	remaining: 1.15s
# 1133:	learn: 0.4100551	total: 28.4s	remaining: 1.13s
# 1134:	learn: 0.4100512	total: 28.4s	remaining: 1.1s
# 1135:	learn: 0.4100431	total: 28.5s	remaining: 1.08s
# 1136:	learn: 0.4100339	total: 28.5s	remaining: 1.05s
# 1137:	learn: 0.4100266	total: 28.5s	remaining: 1.03s
# 1138:	learn: 0.4100199	total: 28.5s	remaining: 1s
# 1139:	learn: 0.4100135	total: 28.5s	remaining: 976ms
# 1140:	learn: 0.4100054	total: 28.6s	remaining: 951ms
# 1141:	learn: 0.4100009	total: 28.6s	remaining: 926ms
# 1142:	learn: 0.4099951	total: 28.6s	remaining: 901ms
# 1143:	learn: 0.4099903	total: 28.6s	remaining: 875ms
# 1144:	learn: 0.4099836	total: 28.6s	remaining: 850ms
# 1145:	learn: 0.4099759	total: 28.6s	remaining: 825ms
# 1146:	learn: 0.4099691	total: 28.7s	remaining: 800ms
# 1147:	learn: 0.4099628	total: 28.7s	remaining: 775ms
# 1148:	learn: 0.4099557	total: 28.7s	remaining: 749ms
# 1149:	learn: 0.4099451	total: 28.7s	remaining: 724ms
# 1150:	learn: 0.4099394	total: 28.7s	remaining: 699ms
# 1151:	learn: 0.4099322	total: 28.8s	remaining: 674ms
# 1152:	learn: 0.4099221	total: 28.8s	remaining: 649ms
# 1153:	learn: 0.4099166	total: 28.8s	remaining: 624ms
# 1154:	learn: 0.4099093	total: 28.8s	remaining: 599ms
# 1155:	learn: 0.4099039	total: 28.8s	remaining: 574ms
# 1156:	learn: 0.4098939	total: 28.9s	remaining: 549ms
# 1157:	learn: 0.4098850	total: 28.9s	remaining: 524ms
# 1158:	learn: 0.4098821	total: 28.9s	remaining: 499ms
# 1159:	learn: 0.4098736	total: 28.9s	remaining: 474ms
# 1160:	learn: 0.4098678	total: 28.9s	remaining: 449ms
# 1161:	learn: 0.4098618	total: 29s	remaining: 424ms
# 1162:	learn: 0.4098539	total: 29s	remaining: 399ms
# 1163:	learn: 0.4098469	total: 29s	remaining: 374ms
# 1164:	learn: 0.4098394	total: 29s	remaining: 349ms
# 1165:	learn: 0.4098334	total: 29.1s	remaining: 324ms
# 1166:	learn: 0.4098236	total: 29.1s	remaining: 299ms
# 1167:	learn: 0.4098171	total: 29.1s	remaining: 274ms
# 1168:	learn: 0.4098068	total: 29.1s	remaining: 249ms
# 1169:	learn: 0.4097978	total: 29.1s	remaining: 224ms
# 1170:	learn: 0.4097913	total: 29.1s	remaining: 199ms
# 1171:	learn: 0.4097826	total: 29.2s	remaining: 174ms
# 1172:	learn: 0.4097755	total: 29.2s	remaining: 149ms
# 1173:	learn: 0.4097651	total: 29.2s	remaining: 124ms
# 1174:	learn: 0.4097554	total: 29.2s	remaining: 99.5ms
# 1175:	learn: 0.4097476	total: 29.3s	remaining: 74.6ms
# 1176:	learn: 0.4097433	total: 29.3s	remaining: 49.7ms
# 1177:	learn: 0.4097347	total: 29.3s	remaining: 24.9ms
# 1178:	learn: 0.4097293	total: 29.3s	remaining: 0us
# 0:	learn: 0.4352773	total: 23ms	remaining: 27.1s
# 1:	learn: 0.4347236	total: 42.9ms	remaining: 25.2s
# 2:	learn: 0.4341832	total: 65.6ms	remaining: 25.7s
# 3:	learn: 0.4336642	total: 85.9ms	remaining: 25.2s
# 4:	learn: 0.4331393	total: 105ms	remaining: 24.8s
# 5:	learn: 0.4326788	total: 125ms	remaining: 24.5s
# 6:	learn: 0.4322256	total: 144ms	remaining: 24.2s
# 7:	learn: 0.4317753	total: 164ms	remaining: 24s
# 8:	learn: 0.4313357	total: 184ms	remaining: 23.9s
# 9:	learn: 0.4308993	total: 203ms	remaining: 23.8s
# 10:	learn: 0.4304889	total: 227ms	remaining: 24.1s
# 11:	learn: 0.4301047	total: 249ms	remaining: 24.2s
# 12:	learn: 0.4297205	total: 269ms	remaining: 24.1s
# 13:	learn: 0.4293587	total: 290ms	remaining: 24.1s
# 14:	learn: 0.4290105	total: 311ms	remaining: 24.1s
# 15:	learn: 0.4286785	total: 332ms	remaining: 24.1s
# 16:	learn: 0.4283606	total: 351ms	remaining: 24s
# 17:	learn: 0.4280371	total: 371ms	remaining: 23.9s
# 18:	learn: 0.4277289	total: 391ms	remaining: 23.9s
# 19:	learn: 0.4274384	total: 409ms	remaining: 23.7s
# 20:	learn: 0.4271662	total: 430ms	remaining: 23.7s
# 21:	learn: 0.4268878	total: 456ms	remaining: 24s
# 22:	learn: 0.4266293	total: 479ms	remaining: 24.1s
# 23:	learn: 0.4263776	total: 498ms	remaining: 23.9s
# 24:	learn: 0.4261334	total: 516ms	remaining: 23.8s
# 25:	learn: 0.4258998	total: 535ms	remaining: 23.7s
# 26:	learn: 0.4256831	total: 553ms	remaining: 23.6s
# 27:	learn: 0.4254506	total: 571ms	remaining: 23.5s
# 28:	learn: 0.4252497	total: 589ms	remaining: 23.3s
# 29:	learn: 0.4250612	total: 608ms	remaining: 23.3s
# 30:	learn: 0.4248717	total: 627ms	remaining: 23.2s
# 31:	learn: 0.4246934	total: 644ms	remaining: 23.1s
# 32:	learn: 0.4245233	total: 673ms	remaining: 23.4s
# 33:	learn: 0.4243419	total: 692ms	remaining: 23.3s
# 34:	learn: 0.4241697	total: 711ms	remaining: 23.3s
# 35:	learn: 0.4240008	total: 731ms	remaining: 23.2s
# 36:	learn: 0.4238467	total: 757ms	remaining: 23.4s
# 37:	learn: 0.4236865	total: 778ms	remaining: 23.4s
# 38:	learn: 0.4235439	total: 797ms	remaining: 23.3s
# 39:	learn: 0.4234008	total: 815ms	remaining: 23.2s
# 40:	learn: 0.4232748	total: 843ms	remaining: 23.4s
# 41:	learn: 0.4231300	total: 886ms	remaining: 24s
# 42:	learn: 0.4230178	total: 929ms	remaining: 24.5s
# 43:	learn: 0.4228946	total: 968ms	remaining: 25s
# 44:	learn: 0.4227686	total: 1.01s	remaining: 25.5s
# 45:	learn: 0.4226527	total: 1.06s	remaining: 26.1s
# 46:	learn: 0.4225315	total: 1.11s	remaining: 26.7s
# 47:	learn: 0.4224152	total: 1.15s	remaining: 27.2s
# 48:	learn: 0.4223014	total: 1.2s	remaining: 27.6s
# 49:	learn: 0.4221952	total: 1.24s	remaining: 28s
# 50:	learn: 0.4220939	total: 1.29s	remaining: 28.5s
# 51:	learn: 0.4219875	total: 1.34s	remaining: 29s
# 52:	learn: 0.4218999	total: 1.39s	remaining: 29.4s
# 53:	learn: 0.4217984	total: 1.43s	remaining: 29.8s
# 54:	learn: 0.4217068	total: 1.48s	remaining: 30.2s
# 55:	learn: 0.4216170	total: 1.5s	remaining: 30.1s
# 56:	learn: 0.4215379	total: 1.55s	remaining: 30.5s
# 57:	learn: 0.4214576	total: 1.59s	remaining: 30.8s
# 58:	learn: 0.4213799	total: 1.64s	remaining: 31.2s
# 59:	learn: 0.4213149	total: 1.69s	remaining: 31.5s
# 60:	learn: 0.4212306	total: 1.74s	remaining: 32s
# 61:	learn: 0.4211593	total: 1.8s	remaining: 32.5s
# 62:	learn: 0.4210876	total: 1.85s	remaining: 32.9s
# 63:	learn: 0.4210172	total: 1.9s	remaining: 33.1s
# 64:	learn: 0.4209422	total: 1.94s	remaining: 33.3s
# 65:	learn: 0.4208756	total: 1.99s	remaining: 33.5s
# 66:	learn: 0.4208114	total: 2.04s	remaining: 33.8s
# 67:	learn: 0.4207485	total: 2.08s	remaining: 34.1s
# 68:	learn: 0.4206890	total: 2.12s	remaining: 34s
# 69:	learn: 0.4206175	total: 2.16s	remaining: 34.3s
# 70:	learn: 0.4205579	total: 2.22s	remaining: 34.6s
# 71:	learn: 0.4205047	total: 2.26s	remaining: 34.8s
# 72:	learn: 0.4204458	total: 2.31s	remaining: 35s
# 73:	learn: 0.4203893	total: 2.36s	remaining: 35.2s
# 74:	learn: 0.4203332	total: 2.41s	remaining: 35.5s
# 75:	learn: 0.4202833	total: 2.47s	remaining: 35.8s
# 76:	learn: 0.4202295	total: 2.51s	remaining: 36s
# 77:	learn: 0.4201813	total: 2.55s	remaining: 36s
# 78:	learn: 0.4201351	total: 2.58s	remaining: 35.9s
# 79:	learn: 0.4200893	total: 2.6s	remaining: 35.8s
# 80:	learn: 0.4200397	total: 2.64s	remaining: 35.8s
# 81:	learn: 0.4199952	total: 2.69s	remaining: 36s
# 82:	learn: 0.4199443	total: 2.73s	remaining: 36.1s
# 83:	learn: 0.4199045	total: 2.78s	remaining: 36.2s
# 84:	learn: 0.4198688	total: 2.83s	remaining: 36.4s
# 85:	learn: 0.4198351	total: 2.87s	remaining: 36.5s
# 86:	learn: 0.4197934	total: 2.92s	remaining: 36.6s
# 87:	learn: 0.4197525	total: 2.96s	remaining: 36.7s
# 88:	learn: 0.4197163	total: 3s	remaining: 36.8s
# 89:	learn: 0.4196731	total: 3.04s	remaining: 36.8s
# 90:	learn: 0.4196482	total: 3.08s	remaining: 36.8s
# 91:	learn: 0.4196132	total: 3.12s	remaining: 36.9s
# 92:	learn: 0.4195742	total: 3.17s	remaining: 37s
# 93:	learn: 0.4195381	total: 3.2s	remaining: 37s
# 94:	learn: 0.4194971	total: 3.24s	remaining: 37s
# 95:	learn: 0.4194624	total: 3.28s	remaining: 37s
# 96:	learn: 0.4194294	total: 3.31s	remaining: 36.9s
# 97:	learn: 0.4193943	total: 3.35s	remaining: 36.9s
# 98:	learn: 0.4193649	total: 3.37s	remaining: 36.8s
# 99:	learn: 0.4193337	total: 3.41s	remaining: 36.8s
# 100:	learn: 0.4192964	total: 3.45s	remaining: 36.8s
# 101:	learn: 0.4192662	total: 3.48s	remaining: 36.8s
# 102:	learn: 0.4192413	total: 3.51s	remaining: 36.7s
# 103:	learn: 0.4192079	total: 3.54s	remaining: 36.6s
# 104:	learn: 0.4191754	total: 3.58s	remaining: 36.6s
# 105:	learn: 0.4191473	total: 3.63s	remaining: 36.7s
# 106:	learn: 0.4191203	total: 3.66s	remaining: 36.6s
# 107:	learn: 0.4190894	total: 3.69s	remaining: 36.6s
# 108:	learn: 0.4190560	total: 3.71s	remaining: 36.4s
# 109:	learn: 0.4190264	total: 3.73s	remaining: 36.3s
# 110:	learn: 0.4190009	total: 3.76s	remaining: 36.2s
# 111:	learn: 0.4189759	total: 3.81s	remaining: 36.3s
# 112:	learn: 0.4189489	total: 3.86s	remaining: 36.4s
# 113:	learn: 0.4189226	total: 3.91s	remaining: 36.5s
# 114:	learn: 0.4188924	total: 3.96s	remaining: 36.7s
# 115:	learn: 0.4188733	total: 4.01s	remaining: 36.7s
# 116:	learn: 0.4188468	total: 4.06s	remaining: 36.9s
# 117:	learn: 0.4188249	total: 4.1s	remaining: 36.9s
# 118:	learn: 0.4188023	total: 4.15s	remaining: 37s
# 119:	learn: 0.4187795	total: 4.2s	remaining: 37.1s
# 120:	learn: 0.4187573	total: 4.25s	remaining: 37.1s
# 121:	learn: 0.4187362	total: 4.3s	remaining: 37.2s
# 122:	learn: 0.4187133	total: 4.34s	remaining: 37.3s
# 123:	learn: 0.4186897	total: 4.39s	remaining: 37.3s
# 124:	learn: 0.4186619	total: 4.44s	remaining: 37.4s
# 125:	learn: 0.4186438	total: 4.47s	remaining: 37.3s
# 126:	learn: 0.4186226	total: 4.49s	remaining: 37.2s
# 127:	learn: 0.4186015	total: 4.53s	remaining: 37.2s
# 128:	learn: 0.4185799	total: 4.58s	remaining: 37.3s
# 129:	learn: 0.4185565	total: 4.63s	remaining: 37.3s
# 130:	learn: 0.4185366	total: 4.67s	remaining: 37.4s
# 131:	learn: 0.4185156	total: 4.71s	remaining: 37.4s
# 132:	learn: 0.4184981	total: 4.76s	remaining: 37.5s
# 133:	learn: 0.4184836	total: 4.81s	remaining: 37.5s
# 134:	learn: 0.4184631	total: 4.86s	remaining: 37.6s
# 135:	learn: 0.4184440	total: 4.91s	remaining: 37.7s
# 136:	learn: 0.4184276	total: 4.96s	remaining: 37.7s
# 137:	learn: 0.4184068	total: 5s	remaining: 37.7s
# 138:	learn: 0.4183874	total: 5.04s	remaining: 37.7s
# 139:	learn: 0.4183708	total: 5.06s	remaining: 37.6s
# 140:	learn: 0.4183472	total: 5.09s	remaining: 37.5s
# 141:	learn: 0.4183277	total: 5.11s	remaining: 37.4s
# 142:	learn: 0.4183116	total: 5.15s	remaining: 37.3s
# 143:	learn: 0.4182905	total: 5.18s	remaining: 37.3s
# 144:	learn: 0.4182718	total: 5.22s	remaining: 37.2s
# 145:	learn: 0.4182551	total: 5.25s	remaining: 37.1s
# 146:	learn: 0.4182405	total: 5.27s	remaining: 37s
# 147:	learn: 0.4182263	total: 5.29s	remaining: 36.8s
# 148:	learn: 0.4182104	total: 5.31s	remaining: 36.7s
# 149:	learn: 0.4181904	total: 5.33s	remaining: 36.6s
# 150:	learn: 0.4181776	total: 5.37s	remaining: 36.6s
# 151:	learn: 0.4181600	total: 5.41s	remaining: 36.6s
# 152:	learn: 0.4181369	total: 5.46s	remaining: 36.6s
# 153:	learn: 0.4181226	total: 5.5s	remaining: 36.6s
# 154:	learn: 0.4181079	total: 5.54s	remaining: 36.6s
# 155:	learn: 0.4180934	total: 5.58s	remaining: 36.6s
# 156:	learn: 0.4180806	total: 5.62s	remaining: 36.6s
# 157:	learn: 0.4180590	total: 5.67s	remaining: 36.7s
# 158:	learn: 0.4180391	total: 5.72s	remaining: 36.7s
# 159:	learn: 0.4180253	total: 5.76s	remaining: 36.7s
# 160:	learn: 0.4180107	total: 5.8s	remaining: 36.7s
# 161:	learn: 0.4179950	total: 5.82s	remaining: 36.6s
# 162:	learn: 0.4179792	total: 5.87s	remaining: 36.6s
# 163:	learn: 0.4179629	total: 5.92s	remaining: 36.6s
# 164:	learn: 0.4179430	total: 5.96s	remaining: 36.7s
# 165:	learn: 0.4179255	total: 6s	remaining: 36.6s
# 166:	learn: 0.4179083	total: 6.05s	remaining: 36.7s
# 167:	learn: 0.4178901	total: 6.1s	remaining: 36.7s
# 168:	learn: 0.4178741	total: 6.16s	remaining: 36.8s
# 169:	learn: 0.4178563	total: 6.21s	remaining: 36.9s
# 170:	learn: 0.4178460	total: 6.25s	remaining: 36.8s
# 171:	learn: 0.4178344	total: 6.29s	remaining: 36.8s
# 172:	learn: 0.4178199	total: 6.33s	remaining: 36.8s
# 173:	learn: 0.4178022	total: 6.37s	remaining: 36.8s
# 174:	learn: 0.4177875	total: 6.42s	remaining: 36.8s
# 175:	learn: 0.4177738	total: 6.44s	remaining: 36.7s
# 176:	learn: 0.4177627	total: 6.46s	remaining: 36.6s
# 177:	learn: 0.4177482	total: 6.49s	remaining: 36.5s
# 178:	learn: 0.4177347	total: 6.52s	remaining: 36.4s
# 179:	learn: 0.4177218	total: 6.56s	remaining: 36.4s
# 180:	learn: 0.4177098	total: 6.6s	remaining: 36.4s
# 181:	learn: 0.4176936	total: 6.64s	remaining: 36.4s
# 182:	learn: 0.4176785	total: 6.69s	remaining: 36.4s
# 183:	learn: 0.4176661	total: 6.74s	remaining: 36.5s
# 184:	learn: 0.4176478	total: 6.79s	remaining: 36.5s
# 185:	learn: 0.4176372	total: 6.84s	remaining: 36.5s
# 186:	learn: 0.4176267	total: 6.88s	remaining: 36.5s
# 187:	learn: 0.4176138	total: 6.91s	remaining: 36.4s
# 188:	learn: 0.4176018	total: 6.96s	remaining: 36.4s
# 189:	learn: 0.4175921	total: 7s	remaining: 36.4s
# 190:	learn: 0.4175807	total: 7.03s	remaining: 36.4s
# 191:	learn: 0.4175704	total: 7.05s	remaining: 36.3s
# 192:	learn: 0.4175574	total: 7.07s	remaining: 36.1s
# 193:	learn: 0.4175439	total: 7.09s	remaining: 36s
# 194:	learn: 0.4175311	total: 7.11s	remaining: 35.9s
# 195:	learn: 0.4175185	total: 7.13s	remaining: 35.8s
# 196:	learn: 0.4175080	total: 7.15s	remaining: 35.6s
# 197:	learn: 0.4174969	total: 7.17s	remaining: 35.5s
# 198:	learn: 0.4174878	total: 7.19s	remaining: 35.4s
# 199:	learn: 0.4174754	total: 7.21s	remaining: 35.3s
# 200:	learn: 0.4174595	total: 7.23s	remaining: 35.2s
# 201:	learn: 0.4174515	total: 7.26s	remaining: 35.1s
# 202:	learn: 0.4174407	total: 7.28s	remaining: 35s
# 203:	learn: 0.4174272	total: 7.3s	remaining: 34.9s
# 204:	learn: 0.4174170	total: 7.32s	remaining: 34.8s
# 205:	learn: 0.4174061	total: 7.33s	remaining: 34.6s
# 206:	learn: 0.4173950	total: 7.35s	remaining: 34.5s
# 207:	learn: 0.4173830	total: 7.37s	remaining: 34.4s
# 208:	learn: 0.4173696	total: 7.39s	remaining: 34.3s
# 209:	learn: 0.4173586	total: 7.41s	remaining: 34.2s
# 210:	learn: 0.4173490	total: 7.42s	remaining: 34.1s
# 211:	learn: 0.4173383	total: 7.44s	remaining: 33.9s
# 212:	learn: 0.4173275	total: 7.46s	remaining: 33.8s
# 213:	learn: 0.4173199	total: 7.49s	remaining: 33.8s
# 214:	learn: 0.4173104	total: 7.5s	remaining: 33.6s
# 215:	learn: 0.4172989	total: 7.52s	remaining: 33.5s
# 216:	learn: 0.4172878	total: 7.54s	remaining: 33.4s
# 217:	learn: 0.4172727	total: 7.56s	remaining: 33.3s
# 218:	learn: 0.4172606	total: 7.58s	remaining: 33.2s
# 219:	learn: 0.4172545	total: 7.6s	remaining: 33.1s
# 220:	learn: 0.4172441	total: 7.62s	remaining: 33s
# 221:	learn: 0.4172333	total: 7.64s	remaining: 32.9s
# 222:	learn: 0.4172153	total: 7.66s	remaining: 32.8s
# 223:	learn: 0.4172024	total: 7.67s	remaining: 32.7s
# 224:	learn: 0.4171906	total: 7.7s	remaining: 32.7s
# 225:	learn: 0.4171785	total: 7.72s	remaining: 32.6s
# 226:	learn: 0.4171704	total: 7.74s	remaining: 32.5s
# 227:	learn: 0.4171606	total: 7.75s	remaining: 32.3s
# 228:	learn: 0.4171478	total: 7.77s	remaining: 32.2s
# 229:	learn: 0.4171341	total: 7.79s	remaining: 32.1s
# 230:	learn: 0.4171254	total: 7.81s	remaining: 32s
# 231:	learn: 0.4171118	total: 7.83s	remaining: 31.9s
# 232:	learn: 0.4171025	total: 7.84s	remaining: 31.9s
# 233:	learn: 0.4170918	total: 7.86s	remaining: 31.8s
# 234:	learn: 0.4170816	total: 7.88s	remaining: 31.7s
# 235:	learn: 0.4170715	total: 7.9s	remaining: 31.6s
# 236:	learn: 0.4170614	total: 7.94s	remaining: 31.5s
# 237:	learn: 0.4170518	total: 7.96s	remaining: 31.5s
# 238:	learn: 0.4170368	total: 7.97s	remaining: 31.4s
# 239:	learn: 0.4170288	total: 7.99s	remaining: 31.3s
# 240:	learn: 0.4170169	total: 8.01s	remaining: 31.2s
# 241:	learn: 0.4170072	total: 8.03s	remaining: 31.1s
# 242:	learn: 0.4169936	total: 8.05s	remaining: 31s
# 243:	learn: 0.4169829	total: 8.07s	remaining: 30.9s
# 244:	learn: 0.4169705	total: 8.09s	remaining: 30.8s
# 245:	learn: 0.4169611	total: 8.11s	remaining: 30.7s
# 246:	learn: 0.4169485	total: 8.13s	remaining: 30.7s
# 247:	learn: 0.4169385	total: 8.15s	remaining: 30.6s
# 248:	learn: 0.4169243	total: 8.17s	remaining: 30.5s
# 249:	learn: 0.4169167	total: 8.19s	remaining: 30.4s
# 250:	learn: 0.4169084	total: 8.21s	remaining: 30.3s
# 251:	learn: 0.4169015	total: 8.22s	remaining: 30.3s
# 252:	learn: 0.4168900	total: 8.24s	remaining: 30.2s
# 253:	learn: 0.4168816	total: 8.26s	remaining: 30.1s
# 254:	learn: 0.4168694	total: 8.28s	remaining: 30s
# 255:	learn: 0.4168581	total: 8.3s	remaining: 29.9s
# 256:	learn: 0.4168519	total: 8.32s	remaining: 29.9s
# 257:	learn: 0.4168439	total: 8.34s	remaining: 29.8s
# 258:	learn: 0.4168340	total: 8.38s	remaining: 29.7s
# 259:	learn: 0.4168230	total: 8.4s	remaining: 29.7s
# 260:	learn: 0.4168165	total: 8.42s	remaining: 29.6s
# 261:	learn: 0.4168115	total: 8.44s	remaining: 29.5s
# 262:	learn: 0.4168018	total: 8.46s	remaining: 29.5s
# 263:	learn: 0.4167899	total: 8.48s	remaining: 29.4s
# 264:	learn: 0.4167828	total: 8.5s	remaining: 29.3s
# 265:	learn: 0.4167749	total: 8.52s	remaining: 29.2s
# 266:	learn: 0.4167648	total: 8.54s	remaining: 29.2s
# 267:	learn: 0.4167571	total: 8.56s	remaining: 29.1s
# 268:	learn: 0.4167437	total: 8.59s	remaining: 29s
# 269:	learn: 0.4167302	total: 8.6s	remaining: 29s
# 270:	learn: 0.4167223	total: 8.63s	remaining: 28.9s
# 271:	learn: 0.4167123	total: 8.65s	remaining: 28.8s
# 272:	learn: 0.4167054	total: 8.66s	remaining: 28.8s
# 273:	learn: 0.4166879	total: 8.69s	remaining: 28.7s
# 274:	learn: 0.4166811	total: 8.7s	remaining: 28.6s
# 275:	learn: 0.4166732	total: 8.72s	remaining: 28.5s
# 276:	learn: 0.4166615	total: 8.74s	remaining: 28.5s
# 277:	learn: 0.4166542	total: 8.76s	remaining: 28.4s
# 278:	learn: 0.4166466	total: 8.78s	remaining: 28.3s
# 279:	learn: 0.4166390	total: 8.81s	remaining: 28.3s
# 280:	learn: 0.4166292	total: 8.83s	remaining: 28.2s
# 281:	learn: 0.4166220	total: 8.85s	remaining: 28.1s
# 282:	learn: 0.4166114	total: 8.87s	remaining: 28.1s
# 283:	learn: 0.4166038	total: 8.88s	remaining: 28s
# 284:	learn: 0.4165976	total: 8.9s	remaining: 27.9s
# 285:	learn: 0.4165883	total: 8.93s	remaining: 27.9s
# 286:	learn: 0.4165801	total: 8.95s	remaining: 27.8s
# 287:	learn: 0.4165725	total: 8.97s	remaining: 27.8s
# 288:	learn: 0.4165636	total: 8.99s	remaining: 27.7s
# 289:	learn: 0.4165557	total: 9.01s	remaining: 27.6s
# 290:	learn: 0.4165502	total: 9.04s	remaining: 27.6s
# 291:	learn: 0.4165404	total: 9.05s	remaining: 27.5s
# 292:	learn: 0.4165335	total: 9.07s	remaining: 27.4s
# 293:	learn: 0.4165246	total: 9.09s	remaining: 27.4s
# 294:	learn: 0.4165141	total: 9.11s	remaining: 27.3s
# 295:	learn: 0.4165018	total: 9.13s	remaining: 27.2s
# 296:	learn: 0.4164937	total: 9.15s	remaining: 27.2s
# 297:	learn: 0.4164868	total: 9.17s	remaining: 27.1s
# 298:	learn: 0.4164790	total: 9.19s	remaining: 27s
# 299:	learn: 0.4164716	total: 9.21s	remaining: 27s
# 300:	learn: 0.4164636	total: 9.23s	remaining: 26.9s
# 301:	learn: 0.4164564	total: 9.25s	remaining: 26.9s
# 302:	learn: 0.4164473	total: 9.27s	remaining: 26.8s
# 303:	learn: 0.4164408	total: 9.29s	remaining: 26.7s
# 304:	learn: 0.4164354	total: 9.31s	remaining: 26.7s
# 305:	learn: 0.4164271	total: 9.33s	remaining: 26.6s
# 306:	learn: 0.4164269	total: 9.34s	remaining: 26.5s
# 307:	learn: 0.4164136	total: 9.36s	remaining: 26.5s
# 308:	learn: 0.4164046	total: 9.38s	remaining: 26.4s
# 309:	learn: 0.4164006	total: 9.4s	remaining: 26.4s
# 310:	learn: 0.4163926	total: 9.42s	remaining: 26.3s
# 311:	learn: 0.4163802	total: 9.45s	remaining: 26.3s
# 312:	learn: 0.4163693	total: 9.47s	remaining: 26.2s
# 313:	learn: 0.4163653	total: 9.49s	remaining: 26.1s
# 314:	learn: 0.4163579	total: 9.51s	remaining: 26.1s
# 315:	learn: 0.4163484	total: 9.53s	remaining: 26s
# 316:	learn: 0.4163392	total: 9.55s	remaining: 26s
# 317:	learn: 0.4163256	total: 9.57s	remaining: 25.9s
# 318:	learn: 0.4163176	total: 9.59s	remaining: 25.9s
# 319:	learn: 0.4163080	total: 9.61s	remaining: 25.8s
# 320:	learn: 0.4163005	total: 9.63s	remaining: 25.7s
# 321:	learn: 0.4162912	total: 9.64s	remaining: 25.7s
# 322:	learn: 0.4162821	total: 9.68s	remaining: 25.6s
# 323:	learn: 0.4162754	total: 9.69s	remaining: 25.6s
# 324:	learn: 0.4162696	total: 9.71s	remaining: 25.5s
# 325:	learn: 0.4162611	total: 9.73s	remaining: 25.5s
# 326:	learn: 0.4162509	total: 9.75s	remaining: 25.4s
# 327:	learn: 0.4162441	total: 9.77s	remaining: 25.3s
# 328:	learn: 0.4162349	total: 9.79s	remaining: 25.3s
# 329:	learn: 0.4162274	total: 9.8s	remaining: 25.2s
# 330:	learn: 0.4162202	total: 9.82s	remaining: 25.2s
# 331:	learn: 0.4162099	total: 9.84s	remaining: 25.1s
# 332:	learn: 0.4162048	total: 9.86s	remaining: 25.1s
# 333:	learn: 0.4161939	total: 9.88s	remaining: 25s
# 334:	learn: 0.4161884	total: 9.9s	remaining: 24.9s
# 335:	learn: 0.4161777	total: 9.92s	remaining: 24.9s
# 336:	learn: 0.4161712	total: 9.95s	remaining: 24.9s
# 337:	learn: 0.4161641	total: 9.97s	remaining: 24.8s
# 338:	learn: 0.4161562	total: 9.99s	remaining: 24.8s
# 339:	learn: 0.4161511	total: 10s	remaining: 24.7s
# 340:	learn: 0.4161413	total: 10s	remaining: 24.6s
# 341:	learn: 0.4161353	total: 10s	remaining: 24.6s
# 342:	learn: 0.4161267	total: 10.1s	remaining: 24.5s
# 343:	learn: 0.4161173	total: 10.1s	remaining: 24.5s
# 344:	learn: 0.4161080	total: 10.1s	remaining: 24.4s
# 345:	learn: 0.4160997	total: 10.1s	remaining: 24.4s
# 346:	learn: 0.4160910	total: 10.1s	remaining: 24.3s
# 347:	learn: 0.4160824	total: 10.2s	remaining: 24.3s
# 348:	learn: 0.4160765	total: 10.2s	remaining: 24.2s
# 349:	learn: 0.4160691	total: 10.2s	remaining: 24.2s
# 350:	learn: 0.4160620	total: 10.2s	remaining: 24.1s
# 351:	learn: 0.4160541	total: 10.2s	remaining: 24.1s
# 352:	learn: 0.4160421	total: 10.3s	remaining: 24s
# 353:	learn: 0.4160326	total: 10.3s	remaining: 23.9s
# 354:	learn: 0.4160242	total: 10.3s	remaining: 23.9s
# 355:	learn: 0.4160192	total: 10.3s	remaining: 23.9s
# 356:	learn: 0.4160122	total: 10.3s	remaining: 23.8s
# 357:	learn: 0.4160070	total: 10.4s	remaining: 23.8s
# 358:	learn: 0.4159978	total: 10.4s	remaining: 23.7s
# 359:	learn: 0.4159895	total: 10.4s	remaining: 23.7s
# 360:	learn: 0.4159811	total: 10.4s	remaining: 23.6s
# 361:	learn: 0.4159747	total: 10.4s	remaining: 23.5s
# 362:	learn: 0.4159693	total: 10.4s	remaining: 23.5s
# 363:	learn: 0.4159632	total: 10.5s	remaining: 23.4s
# 364:	learn: 0.4159584	total: 10.5s	remaining: 23.4s
# 365:	learn: 0.4159514	total: 10.5s	remaining: 23.3s
# 366:	learn: 0.4159454	total: 10.5s	remaining: 23.3s
# 367:	learn: 0.4159384	total: 10.5s	remaining: 23.2s
# 368:	learn: 0.4159307	total: 10.6s	remaining: 23.2s
# 369:	learn: 0.4159204	total: 10.6s	remaining: 23.1s
# 370:	learn: 0.4159112	total: 10.6s	remaining: 23.1s
# 371:	learn: 0.4159014	total: 10.6s	remaining: 23s
# 372:	learn: 0.4158946	total: 10.6s	remaining: 23s
# 373:	learn: 0.4158865	total: 10.7s	remaining: 22.9s
# 374:	learn: 0.4158787	total: 10.7s	remaining: 22.9s
# 375:	learn: 0.4158686	total: 10.7s	remaining: 22.8s
# 376:	learn: 0.4158577	total: 10.7s	remaining: 22.8s
# 377:	learn: 0.4158490	total: 10.7s	remaining: 22.7s
# 378:	learn: 0.4158434	total: 10.8s	remaining: 22.7s
# 379:	learn: 0.4158379	total: 10.8s	remaining: 22.7s
# 380:	learn: 0.4158319	total: 10.8s	remaining: 22.6s
# 381:	learn: 0.4158241	total: 10.8s	remaining: 22.6s
# 382:	learn: 0.4158131	total: 10.8s	remaining: 22.5s
# 383:	learn: 0.4158062	total: 10.9s	remaining: 22.5s
# 384:	learn: 0.4157986	total: 10.9s	remaining: 22.4s
# 385:	learn: 0.4157939	total: 10.9s	remaining: 22.4s
# 386:	learn: 0.4157868	total: 10.9s	remaining: 22.3s
# 387:	learn: 0.4157750	total: 10.9s	remaining: 22.3s
# 388:	learn: 0.4157662	total: 11s	remaining: 22.3s
# 389:	learn: 0.4157615	total: 11s	remaining: 22.2s
# 390:	learn: 0.4157556	total: 11s	remaining: 22.2s
# 391:	learn: 0.4157451	total: 11s	remaining: 22.1s
# 392:	learn: 0.4157378	total: 11s	remaining: 22.1s
# 393:	learn: 0.4157315	total: 11.1s	remaining: 22.1s
# 394:	learn: 0.4157218	total: 11.1s	remaining: 22s
# 395:	learn: 0.4157170	total: 11.1s	remaining: 22s
# 396:	learn: 0.4157118	total: 11.1s	remaining: 21.9s
# 397:	learn: 0.4157039	total: 11.1s	remaining: 21.9s
# 398:	learn: 0.4156909	total: 11.2s	remaining: 21.8s
# 399:	learn: 0.4156832	total: 11.2s	remaining: 21.8s
# 400:	learn: 0.4156767	total: 11.2s	remaining: 21.8s
# 401:	learn: 0.4156692	total: 11.2s	remaining: 21.7s
# 402:	learn: 0.4156592	total: 11.3s	remaining: 21.7s
# 403:	learn: 0.4156523	total: 11.3s	remaining: 21.6s
# 404:	learn: 0.4156470	total: 11.3s	remaining: 21.6s
# 405:	learn: 0.4156410	total: 11.3s	remaining: 21.5s
# 406:	learn: 0.4156351	total: 11.3s	remaining: 21.5s
# 407:	learn: 0.4156288	total: 11.3s	remaining: 21.4s
# 408:	learn: 0.4156226	total: 11.4s	remaining: 21.4s
# 409:	learn: 0.4156144	total: 11.4s	remaining: 21.4s
# 410:	learn: 0.4156092	total: 11.4s	remaining: 21.3s
# 411:	learn: 0.4156025	total: 11.4s	remaining: 21.3s
# 412:	learn: 0.4155962	total: 11.5s	remaining: 21.2s
# 413:	learn: 0.4155911	total: 11.5s	remaining: 21.2s
# 414:	learn: 0.4155811	total: 11.5s	remaining: 21.2s
# 415:	learn: 0.4155718	total: 11.5s	remaining: 21.1s
# 416:	learn: 0.4155668	total: 11.5s	remaining: 21.1s
# 417:	learn: 0.4155590	total: 11.5s	remaining: 21s
# 418:	learn: 0.4155539	total: 11.6s	remaining: 21s
# 419:	learn: 0.4155448	total: 11.6s	remaining: 20.9s
# 420:	learn: 0.4155366	total: 11.6s	remaining: 20.9s
# 421:	learn: 0.4155299	total: 11.6s	remaining: 20.9s
# 422:	learn: 0.4155258	total: 11.6s	remaining: 20.8s
# 423:	learn: 0.4155204	total: 11.7s	remaining: 20.8s
# 424:	learn: 0.4155118	total: 11.7s	remaining: 20.7s
# 425:	learn: 0.4155052	total: 11.7s	remaining: 20.7s
# 426:	learn: 0.4154977	total: 11.7s	remaining: 20.6s
# 427:	learn: 0.4154895	total: 11.7s	remaining: 20.6s
# 428:	learn: 0.4154819	total: 11.8s	remaining: 20.5s
# 429:	learn: 0.4154717	total: 11.8s	remaining: 20.5s
# 430:	learn: 0.4154628	total: 11.8s	remaining: 20.5s
# 431:	learn: 0.4154589	total: 11.8s	remaining: 20.4s
# 432:	learn: 0.4154539	total: 11.8s	remaining: 20.4s
# 433:	learn: 0.4154479	total: 11.9s	remaining: 20.3s
# 434:	learn: 0.4154400	total: 11.9s	remaining: 20.3s
# 435:	learn: 0.4154337	total: 11.9s	remaining: 20.3s
# 436:	learn: 0.4154248	total: 11.9s	remaining: 20.2s
# 437:	learn: 0.4154166	total: 11.9s	remaining: 20.2s
# 438:	learn: 0.4154107	total: 11.9s	remaining: 20.1s
# 439:	learn: 0.4154035	total: 12s	remaining: 20.1s
# 440:	learn: 0.4153956	total: 12s	remaining: 20.1s
# 441:	learn: 0.4153860	total: 12s	remaining: 20s
# 442:	learn: 0.4153756	total: 12s	remaining: 20s
# 443:	learn: 0.4153697	total: 12.1s	remaining: 20s
# 444:	learn: 0.4153637	total: 12.1s	remaining: 19.9s
# 445:	learn: 0.4153573	total: 12.1s	remaining: 19.9s
# 446:	learn: 0.4153519	total: 12.1s	remaining: 19.9s
# 447:	learn: 0.4153452	total: 12.1s	remaining: 19.8s
# 448:	learn: 0.4153409	total: 12.2s	remaining: 19.8s
# 449:	learn: 0.4153332	total: 12.2s	remaining: 19.7s
# 450:	learn: 0.4153273	total: 12.2s	remaining: 19.7s
# 451:	learn: 0.4153198	total: 12.2s	remaining: 19.7s
# 452:	learn: 0.4153118	total: 12.3s	remaining: 19.6s
# 453:	learn: 0.4152989	total: 12.3s	remaining: 19.6s
# 454:	learn: 0.4152919	total: 12.3s	remaining: 19.6s
# 455:	learn: 0.4152868	total: 12.3s	remaining: 19.5s
# 456:	learn: 0.4152835	total: 12.3s	remaining: 19.5s
# 457:	learn: 0.4152785	total: 12.3s	remaining: 19.4s
# 458:	learn: 0.4152723	total: 12.4s	remaining: 19.4s
# 459:	learn: 0.4152675	total: 12.4s	remaining: 19.4s
# 460:	learn: 0.4152629	total: 12.4s	remaining: 19.3s
# 461:	learn: 0.4152553	total: 12.4s	remaining: 19.3s
# 462:	learn: 0.4152487	total: 12.4s	remaining: 19.2s
# 463:	learn: 0.4152408	total: 12.5s	remaining: 19.2s
# 464:	learn: 0.4152351	total: 12.5s	remaining: 19.2s
# 465:	learn: 0.4152273	total: 12.5s	remaining: 19.1s
# 466:	learn: 0.4152207	total: 12.5s	remaining: 19.1s
# 467:	learn: 0.4152125	total: 12.6s	remaining: 19.1s
# 468:	learn: 0.4152031	total: 12.6s	remaining: 19s
# 469:	learn: 0.4151993	total: 12.6s	remaining: 19s
# 470:	learn: 0.4151923	total: 12.6s	remaining: 18.9s
# 471:	learn: 0.4151846	total: 12.6s	remaining: 18.9s
# 472:	learn: 0.4151787	total: 12.6s	remaining: 18.9s
# 473:	learn: 0.4151708	total: 12.7s	remaining: 18.8s
# 474:	learn: 0.4151600	total: 12.7s	remaining: 18.8s
# 475:	learn: 0.4151526	total: 12.7s	remaining: 18.8s
# 476:	learn: 0.4151481	total: 12.7s	remaining: 18.7s
# 477:	learn: 0.4151373	total: 12.8s	remaining: 18.7s
# 478:	learn: 0.4151325	total: 12.8s	remaining: 18.7s
# 479:	learn: 0.4151242	total: 12.8s	remaining: 18.6s
# 480:	learn: 0.4151185	total: 12.8s	remaining: 18.6s
# 481:	learn: 0.4151130	total: 12.8s	remaining: 18.6s
# 482:	learn: 0.4151053	total: 12.9s	remaining: 18.5s
# 483:	learn: 0.4151006	total: 12.9s	remaining: 18.5s
# 484:	learn: 0.4150938	total: 12.9s	remaining: 18.5s
# 485:	learn: 0.4150875	total: 12.9s	remaining: 18.4s
# 486:	learn: 0.4150796	total: 12.9s	remaining: 18.4s
# 487:	learn: 0.4150732	total: 13s	remaining: 18.3s
# 488:	learn: 0.4150686	total: 13s	remaining: 18.3s
# 489:	learn: 0.4150599	total: 13s	remaining: 18.3s
# 490:	learn: 0.4150560	total: 13s	remaining: 18.3s
# 491:	learn: 0.4150439	total: 13s	remaining: 18.2s
# 492:	learn: 0.4150347	total: 13.1s	remaining: 18.2s
# 493:	learn: 0.4150292	total: 13.1s	remaining: 18.1s
# 494:	learn: 0.4150204	total: 13.1s	remaining: 18.1s
# 495:	learn: 0.4150084	total: 13.1s	remaining: 18.1s
# 496:	learn: 0.4150034	total: 13.2s	remaining: 18.1s
# 497:	learn: 0.4149972	total: 13.2s	remaining: 18s
# 498:	learn: 0.4149883	total: 13.2s	remaining: 18s
# 499:	learn: 0.4149839	total: 13.2s	remaining: 18s
# 500:	learn: 0.4149744	total: 13.2s	remaining: 17.9s
# 501:	learn: 0.4149689	total: 13.3s	remaining: 17.9s
# 502:	learn: 0.4149631	total: 13.3s	remaining: 17.8s
# 503:	learn: 0.4149556	total: 13.3s	remaining: 17.8s
# 504:	learn: 0.4149494	total: 13.3s	remaining: 17.8s
# 505:	learn: 0.4149426	total: 13.3s	remaining: 17.8s
# 506:	learn: 0.4149355	total: 13.4s	remaining: 17.7s
# 507:	learn: 0.4149267	total: 13.4s	remaining: 17.7s
# 508:	learn: 0.4149209	total: 13.4s	remaining: 17.6s
# 509:	learn: 0.4149116	total: 13.4s	remaining: 17.6s
# 510:	learn: 0.4149017	total: 13.4s	remaining: 17.6s
# 511:	learn: 0.4148929	total: 13.5s	remaining: 17.5s
# 512:	learn: 0.4148853	total: 13.5s	remaining: 17.5s
# 513:	learn: 0.4148778	total: 13.5s	remaining: 17.5s
# 514:	learn: 0.4148708	total: 13.5s	remaining: 17.4s
# 515:	learn: 0.4148620	total: 13.5s	remaining: 17.4s
# 516:	learn: 0.4148570	total: 13.6s	remaining: 17.4s
# 517:	learn: 0.4148496	total: 13.6s	remaining: 17.3s
# 518:	learn: 0.4148423	total: 13.6s	remaining: 17.3s
# 519:	learn: 0.4148333	total: 13.6s	remaining: 17.3s
# 520:	learn: 0.4148245	total: 13.6s	remaining: 17.2s
# 521:	learn: 0.4148141	total: 13.7s	remaining: 17.2s
# 522:	learn: 0.4148027	total: 13.7s	remaining: 17.2s
# 523:	learn: 0.4147932	total: 13.7s	remaining: 17.1s
# 524:	learn: 0.4147843	total: 13.7s	remaining: 17.1s
# 525:	learn: 0.4147798	total: 13.7s	remaining: 17.1s
# 526:	learn: 0.4147690	total: 13.8s	remaining: 17s
# 527:	learn: 0.4147602	total: 13.8s	remaining: 17s
# 528:	learn: 0.4147526	total: 13.8s	remaining: 17s
# 529:	learn: 0.4147420	total: 13.8s	remaining: 16.9s
# 530:	learn: 0.4147334	total: 13.8s	remaining: 16.9s
# 531:	learn: 0.4147248	total: 13.9s	remaining: 16.9s
# 532:	learn: 0.4147200	total: 13.9s	remaining: 16.8s
# 533:	learn: 0.4147122	total: 13.9s	remaining: 16.8s
# 534:	learn: 0.4147048	total: 13.9s	remaining: 16.8s
# 535:	learn: 0.4146995	total: 13.9s	remaining: 16.7s
# 536:	learn: 0.4146938	total: 14s	remaining: 16.7s
# 537:	learn: 0.4146874	total: 14s	remaining: 16.7s
# 538:	learn: 0.4146774	total: 14s	remaining: 16.6s
# 539:	learn: 0.4146647	total: 14s	remaining: 16.6s
# 540:	learn: 0.4146577	total: 14.1s	remaining: 16.6s
# 541:	learn: 0.4146499	total: 14.1s	remaining: 16.5s
# 542:	learn: 0.4146433	total: 14.1s	remaining: 16.5s
# 543:	learn: 0.4146342	total: 14.1s	remaining: 16.5s
# 544:	learn: 0.4146294	total: 14.1s	remaining: 16.4s
# 545:	learn: 0.4146221	total: 14.1s	remaining: 16.4s
# 546:	learn: 0.4146132	total: 14.2s	remaining: 16.4s
# 547:	learn: 0.4146072	total: 14.2s	remaining: 16.3s
# 548:	learn: 0.4145993	total: 14.2s	remaining: 16.3s
# 549:	learn: 0.4145883	total: 14.2s	remaining: 16.3s
# 550:	learn: 0.4145799	total: 14.2s	remaining: 16.2s
# 551:	learn: 0.4145729	total: 14.3s	remaining: 16.2s
# 552:	learn: 0.4145634	total: 14.3s	remaining: 16.2s
# 553:	learn: 0.4145569	total: 14.3s	remaining: 16.1s
# 554:	learn: 0.4145517	total: 14.3s	remaining: 16.1s
# 555:	learn: 0.4145463	total: 14.3s	remaining: 16.1s
# 556:	learn: 0.4145393	total: 14.4s	remaining: 16s
# 557:	learn: 0.4145335	total: 14.4s	remaining: 16s
# 558:	learn: 0.4145254	total: 14.4s	remaining: 16s
# 559:	learn: 0.4145193	total: 14.4s	remaining: 16s
# 560:	learn: 0.4145120	total: 14.4s	remaining: 15.9s
# 561:	learn: 0.4145038	total: 14.5s	remaining: 15.9s
# 562:	learn: 0.4144933	total: 14.5s	remaining: 15.9s
# 563:	learn: 0.4144853	total: 14.5s	remaining: 15.8s
# 564:	learn: 0.4144801	total: 14.5s	remaining: 15.8s
# 565:	learn: 0.4144723	total: 14.6s	remaining: 15.8s
# 566:	learn: 0.4144670	total: 14.6s	remaining: 15.7s
# 567:	learn: 0.4144608	total: 14.6s	remaining: 15.7s
# 568:	learn: 0.4144510	total: 14.6s	remaining: 15.7s
# 569:	learn: 0.4144439	total: 14.6s	remaining: 15.6s
# 570:	learn: 0.4144379	total: 14.6s	remaining: 15.6s
# 571:	learn: 0.4144309	total: 14.7s	remaining: 15.6s
# 572:	learn: 0.4144221	total: 14.7s	remaining: 15.5s
# 573:	learn: 0.4144186	total: 14.7s	remaining: 15.5s
# 574:	learn: 0.4144098	total: 14.7s	remaining: 15.5s
# 575:	learn: 0.4144054	total: 14.7s	remaining: 15.4s
# 576:	learn: 0.4143994	total: 14.8s	remaining: 15.4s
# 577:	learn: 0.4143912	total: 14.8s	remaining: 15.4s
# 578:	learn: 0.4143848	total: 14.8s	remaining: 15.3s
# 579:	learn: 0.4143761	total: 14.8s	remaining: 15.3s
# 580:	learn: 0.4143705	total: 14.8s	remaining: 15.3s
# 581:	learn: 0.4143606	total: 14.9s	remaining: 15.2s
# 582:	learn: 0.4143540	total: 14.9s	remaining: 15.2s
# 583:	learn: 0.4143442	total: 14.9s	remaining: 15.2s
# 584:	learn: 0.4143341	total: 14.9s	remaining: 15.1s
# 585:	learn: 0.4143275	total: 14.9s	remaining: 15.1s
# 586:	learn: 0.4143203	total: 15s	remaining: 15.1s
# 587:	learn: 0.4143102	total: 15s	remaining: 15.1s
# 588:	learn: 0.4143037	total: 15s	remaining: 15s
# 589:	learn: 0.4142963	total: 15s	remaining: 15s
# 590:	learn: 0.4142877	total: 15.1s	remaining: 15s
# 591:	learn: 0.4142803	total: 15.1s	remaining: 14.9s
# 592:	learn: 0.4142703	total: 15.1s	remaining: 14.9s
# 593:	learn: 0.4142600	total: 15.1s	remaining: 14.9s
# 594:	learn: 0.4142549	total: 15.1s	remaining: 14.9s
# 595:	learn: 0.4142492	total: 15.2s	remaining: 14.8s
# 596:	learn: 0.4142421	total: 15.2s	remaining: 14.8s
# 597:	learn: 0.4142364	total: 15.2s	remaining: 14.8s
# 598:	learn: 0.4142293	total: 15.2s	remaining: 14.7s
# 599:	learn: 0.4142206	total: 15.2s	remaining: 14.7s
# 600:	learn: 0.4142133	total: 15.3s	remaining: 14.7s
# 601:	learn: 0.4142056	total: 15.3s	remaining: 14.6s
# 602:	learn: 0.4141999	total: 15.3s	remaining: 14.6s
# 603:	learn: 0.4141900	total: 15.3s	remaining: 14.6s
# 604:	learn: 0.4141840	total: 15.3s	remaining: 14.6s
# 605:	learn: 0.4141786	total: 15.4s	remaining: 14.5s
# 606:	learn: 0.4141683	total: 15.4s	remaining: 14.5s
# 607:	learn: 0.4141629	total: 15.4s	remaining: 14.5s
# 608:	learn: 0.4141546	total: 15.4s	remaining: 14.4s
# 609:	learn: 0.4141463	total: 15.4s	remaining: 14.4s
# 610:	learn: 0.4141355	total: 15.5s	remaining: 14.4s
# 611:	learn: 0.4141267	total: 15.5s	remaining: 14.3s
# 612:	learn: 0.4141196	total: 15.5s	remaining: 14.3s
# 613:	learn: 0.4141132	total: 15.5s	remaining: 14.3s
# 614:	learn: 0.4141081	total: 15.5s	remaining: 14.3s
# 615:	learn: 0.4141013	total: 15.6s	remaining: 14.2s
# 616:	learn: 0.4140903	total: 15.6s	remaining: 14.2s
# 617:	learn: 0.4140826	total: 15.6s	remaining: 14.2s
# 618:	learn: 0.4140738	total: 15.6s	remaining: 14.1s
# 619:	learn: 0.4140675	total: 15.6s	remaining: 14.1s
# 620:	learn: 0.4140598	total: 15.6s	remaining: 14.1s
# 621:	learn: 0.4140563	total: 15.7s	remaining: 14s
# 622:	learn: 0.4140483	total: 15.7s	remaining: 14s
# 623:	learn: 0.4140394	total: 15.7s	remaining: 14s
# 624:	learn: 0.4140334	total: 15.7s	remaining: 13.9s
# 625:	learn: 0.4140274	total: 15.7s	remaining: 13.9s
# 626:	learn: 0.4140203	total: 15.8s	remaining: 13.9s
# 627:	learn: 0.4140118	total: 15.8s	remaining: 13.8s
# 628:	learn: 0.4140040	total: 15.8s	remaining: 13.8s
# 629:	learn: 0.4139987	total: 15.8s	remaining: 13.8s
# 630:	learn: 0.4139882	total: 15.8s	remaining: 13.8s
# 631:	learn: 0.4139791	total: 15.9s	remaining: 13.7s
# 632:	learn: 0.4139704	total: 15.9s	remaining: 13.7s
# 633:	learn: 0.4139607	total: 15.9s	remaining: 13.7s
# 634:	learn: 0.4139511	total: 15.9s	remaining: 13.6s
# 635:	learn: 0.4139445	total: 15.9s	remaining: 13.6s
# 636:	learn: 0.4139332	total: 16s	remaining: 13.6s
# 637:	learn: 0.4139224	total: 16s	remaining: 13.5s
# 638:	learn: 0.4139176	total: 16s	remaining: 13.5s
# 639:	learn: 0.4139091	total: 16s	remaining: 13.5s
# 640:	learn: 0.4138992	total: 16s	remaining: 13.5s
# 641:	learn: 0.4138941	total: 16.1s	remaining: 13.4s
# 642:	learn: 0.4138872	total: 16.1s	remaining: 13.4s
# ...
# 874:	learn: 0.4125578	total: 20.6s	remaining: 7.17s
# 875:	learn: 0.4125537	total: 20.6s	remaining: 7.14s
# 876:	learn: 0.4125487	total: 20.7s	remaining: 7.12s
# 877:	learn: 0.4125406	total: 20.7s	remaining: 7.09s
# 878:	learn: 0.4125342	total: 20.7s	remaining: 7.07s
# 879:	learn: 0.4125252	total: 20.7s	remaining: 7.04s
# 880:	learn: 0.4125178	total: 20.7s	remaining: 7.02s
# 881:	learn: 0.4125112	total: 20.8s	remaining: 6.99s
# 882:	learn: 0.4125047	total: 20.8s	remaining: 6.97s
# 883:	learn: 0.4124986	total: 20.8s	remaining: 6.94s
# 884:	learn: 0.4124912	total: 20.8s	remaining: 6.92s
# 885:	learn: 0.4124827	total: 20.8s	remaining: 6.89s
# 886:	learn: 0.4124735	total: 20.9s	remaining: 6.87s
# 887:	learn: 0.4124679	total: 20.9s	remaining: 6.84s
# 888:	learn: 0.4124586	total: 20.9s	remaining: 6.82s
# 889:	learn: 0.4124540	total: 20.9s	remaining: 6.8s
# 890:	learn: 0.4124476	total: 21s	remaining: 6.77s
# 891:	learn: 0.4124414	total: 21s	remaining: 6.75s
# 892:	learn: 0.4124362	total: 21s	remaining: 6.73s
# 893:	learn: 0.4124269	total: 21s	remaining: 6.7s
# 894:	learn: 0.4124208	total: 21s	remaining: 6.67s
# 895:	learn: 0.4124133	total: 21.1s	remaining: 6.65s
# 896:	learn: 0.4124079	total: 21.1s	remaining: 6.63s
# 897:	learn: 0.4124025	total: 21.1s	remaining: 6.6s
# 898:	learn: 0.4123941	total: 21.1s	remaining: 6.58s
# 899:	learn: 0.4123878	total: 21.1s	remaining: 6.55s
# 900:	learn: 0.4123843	total: 21.1s	remaining: 6.53s
# 901:	learn: 0.4123778	total: 21.2s	remaining: 6.5s
# 902:	learn: 0.4123717	total: 21.2s	remaining: 6.48s
# 903:	learn: 0.4123691	total: 21.2s	remaining: 6.45s
# 904:	learn: 0.4123632	total: 21.2s	remaining: 6.43s
# 905:	learn: 0.4123518	total: 21.2s	remaining: 6.4s
# 906:	learn: 0.4123443	total: 21.3s	remaining: 6.38s
# 907:	learn: 0.4123345	total: 21.3s	remaining: 6.35s
# 908:	learn: 0.4123295	total: 21.3s	remaining: 6.33s
# 909:	learn: 0.4123228	total: 21.3s	remaining: 6.3s
# 910:	learn: 0.4123139	total: 21.3s	remaining: 6.28s
# 911:	learn: 0.4123091	total: 21.4s	remaining: 6.25s
# 912:	learn: 0.4123010	total: 21.4s	remaining: 6.23s
# 913:	learn: 0.4122927	total: 21.4s	remaining: 6.21s
# 914:	learn: 0.4122838	total: 21.4s	remaining: 6.18s
# 915:	learn: 0.4122773	total: 21.5s	remaining: 6.16s
# 916:	learn: 0.4122714	total: 21.5s	remaining: 6.14s
# 917:	learn: 0.4122635	total: 21.5s	remaining: 6.11s
# 918:	learn: 0.4122538	total: 21.5s	remaining: 6.09s
# 919:	learn: 0.4122455	total: 21.5s	remaining: 6.06s
# 920:	learn: 0.4122341	total: 21.6s	remaining: 6.04s
# 921:	learn: 0.4122267	total: 21.6s	remaining: 6.01s
# 922:	learn: 0.4122204	total: 21.6s	remaining: 5.99s
# 923:	learn: 0.4122133	total: 21.6s	remaining: 5.96s
# 924:	learn: 0.4122069	total: 21.6s	remaining: 5.94s
# 925:	learn: 0.4121993	total: 21.7s	remaining: 5.92s
# 926:	learn: 0.4121852	total: 21.7s	remaining: 5.89s
# 927:	learn: 0.4121796	total: 21.7s	remaining: 5.87s
# 928:	learn: 0.4121715	total: 21.7s	remaining: 5.84s
# 929:	learn: 0.4121634	total: 21.7s	remaining: 5.82s
# 930:	learn: 0.4121566	total: 21.8s	remaining: 5.8s
# 931:	learn: 0.4121496	total: 21.8s	remaining: 5.77s
# 932:	learn: 0.4121427	total: 21.8s	remaining: 5.75s
# 933:	learn: 0.4121337	total: 21.8s	remaining: 5.72s
# 934:	learn: 0.4121254	total: 21.8s	remaining: 5.7s
# 935:	learn: 0.4121235	total: 21.9s	remaining: 5.67s
# 936:	learn: 0.4121145	total: 21.9s	remaining: 5.65s
# 937:	learn: 0.4121065	total: 21.9s	remaining: 5.63s
# 938:	learn: 0.4120975	total: 21.9s	remaining: 5.6s
# 939:	learn: 0.4120914	total: 21.9s	remaining: 5.58s
# 940:	learn: 0.4120847	total: 22s	remaining: 5.55s
# 941:	learn: 0.4120807	total: 22s	remaining: 5.53s
# 942:	learn: 0.4120728	total: 22s	remaining: 5.5s
# 943:	learn: 0.4120665	total: 22s	remaining: 5.48s
# 944:	learn: 0.4120590	total: 22s	remaining: 5.46s
# 945:	learn: 0.4120505	total: 22.1s	remaining: 5.43s
# 946:	learn: 0.4120418	total: 22.1s	remaining: 5.41s
# 947:	learn: 0.4120358	total: 22.1s	remaining: 5.39s
# 948:	learn: 0.4120310	total: 22.1s	remaining: 5.36s
# 949:	learn: 0.4120217	total: 22.1s	remaining: 5.34s
# 950:	learn: 0.4120163	total: 22.2s	remaining: 5.31s
# 951:	learn: 0.4120119	total: 22.2s	remaining: 5.29s
# 952:	learn: 0.4120040	total: 22.2s	remaining: 5.26s
# 953:	learn: 0.4119962	total: 22.2s	remaining: 5.24s
# 954:	learn: 0.4119903	total: 22.2s	remaining: 5.22s
# 955:	learn: 0.4119854	total: 22.3s	remaining: 5.19s
# 956:	learn: 0.4119793	total: 22.3s	remaining: 5.17s
# 957:	learn: 0.4119736	total: 22.3s	remaining: 5.14s
# 958:	learn: 0.4119666	total: 22.3s	remaining: 5.12s
# 959:	learn: 0.4119613	total: 22.3s	remaining: 5.1s
# 960:	learn: 0.4119534	total: 22.4s	remaining: 5.07s
# 961:	learn: 0.4119458	total: 22.4s	remaining: 5.05s
# 962:	learn: 0.4119376	total: 22.4s	remaining: 5.03s
# 963:	learn: 0.4119301	total: 22.4s	remaining: 5s
# 964:	learn: 0.4119218	total: 22.4s	remaining: 4.98s
# 965:	learn: 0.4119138	total: 22.5s	remaining: 4.95s
# 966:	learn: 0.4119044	total: 22.5s	remaining: 4.93s
# 967:	learn: 0.4118995	total: 22.5s	remaining: 4.9s
# 968:	learn: 0.4118918	total: 22.5s	remaining: 4.88s
# 969:	learn: 0.4118832	total: 22.5s	remaining: 4.86s
# 970:	learn: 0.4118757	total: 22.6s	remaining: 4.83s
# 971:	learn: 0.4118700	total: 22.6s	remaining: 4.81s
# 972:	learn: 0.4118627	total: 22.6s	remaining: 4.79s
# 973:	learn: 0.4118571	total: 22.6s	remaining: 4.76s
# 974:	learn: 0.4118524	total: 22.6s	remaining: 4.74s
# 975:	learn: 0.4118465	total: 22.7s	remaining: 4.71s
# 976:	learn: 0.4118372	total: 22.7s	remaining: 4.69s
# 977:	learn: 0.4118312	total: 22.7s	remaining: 4.66s
# 978:	learn: 0.4118262	total: 22.7s	remaining: 4.64s
# 979:	learn: 0.4118149	total: 22.7s	remaining: 4.62s
# 980:	learn: 0.4118093	total: 22.8s	remaining: 4.59s
# 981:	learn: 0.4118040	total: 22.8s	remaining: 4.57s
# 982:	learn: 0.4117957	total: 22.8s	remaining: 4.55s
# 983:	learn: 0.4117886	total: 22.9s	remaining: 4.53s
# 984:	learn: 0.4117804	total: 22.9s	remaining: 4.51s
# 985:	learn: 0.4117724	total: 22.9s	remaining: 4.49s
# 986:	learn: 0.4117642	total: 23s	remaining: 4.47s
# 987:	learn: 0.4117556	total: 23s	remaining: 4.45s
# 988:	learn: 0.4117477	total: 23.1s	remaining: 4.43s
# 989:	learn: 0.4117399	total: 23.1s	remaining: 4.41s
# 990:	learn: 0.4117341	total: 23.2s	remaining: 4.39s
# 991:	learn: 0.4117261	total: 23.2s	remaining: 4.38s
# 992:	learn: 0.4117166	total: 23.3s	remaining: 4.36s
# 993:	learn: 0.4117071	total: 23.3s	remaining: 4.34s
# 994:	learn: 0.4116961	total: 23.4s	remaining: 4.32s
# 995:	learn: 0.4116886	total: 23.4s	remaining: 4.3s
# 996:	learn: 0.4116815	total: 23.5s	remaining: 4.28s
# 997:	learn: 0.4116780	total: 23.5s	remaining: 4.26s
# 998:	learn: 0.4116676	total: 23.5s	remaining: 4.24s
# 999:	learn: 0.4116599	total: 23.5s	remaining: 4.21s
# 1000:	learn: 0.4116541	total: 23.6s	remaining: 4.19s
# 1001:	learn: 0.4116491	total: 23.6s	remaining: 4.17s
# 1002:	learn: 0.4116453	total: 23.6s	remaining: 4.14s
# 1003:	learn: 0.4116336	total: 23.6s	remaining: 4.12s
# 1004:	learn: 0.4116264	total: 23.7s	remaining: 4.1s
# 1005:	learn: 0.4116195	total: 23.7s	remaining: 4.08s
# 1006:	learn: 0.4116123	total: 23.8s	remaining: 4.06s
# 1007:	learn: 0.4116033	total: 23.8s	remaining: 4.04s
# 1008:	learn: 0.4115950	total: 23.9s	remaining: 4.02s
# 1009:	learn: 0.4115898	total: 23.9s	remaining: 4s
# 1010:	learn: 0.4115829	total: 24s	remaining: 3.98s
# 1011:	learn: 0.4115744	total: 24s	remaining: 3.96s
# 1012:	learn: 0.4115658	total: 24s	remaining: 3.94s
# 1013:	learn: 0.4115596	total: 24s	remaining: 3.91s
# 1014:	learn: 0.4115532	total: 24.1s	remaining: 3.89s
# 1015:	learn: 0.4115483	total: 24.1s	remaining: 3.87s
# 1016:	learn: 0.4115415	total: 24.1s	remaining: 3.84s
# 1017:	learn: 0.4115369	total: 24.2s	remaining: 3.82s
# 1018:	learn: 0.4115274	total: 24.2s	remaining: 3.79s
# 1019:	learn: 0.4115213	total: 24.2s	remaining: 3.77s
# 1020:	learn: 0.4115126	total: 24.2s	remaining: 3.75s
# 1021:	learn: 0.4115025	total: 24.3s	remaining: 3.73s
# 1022:	learn: 0.4114970	total: 24.3s	remaining: 3.71s
# 1023:	learn: 0.4114902	total: 24.4s	remaining: 3.69s
# 1024:	learn: 0.4114848	total: 24.4s	remaining: 3.67s
# 1025:	learn: 0.4114797	total: 24.5s	remaining: 3.65s
# 1026:	learn: 0.4114757	total: 24.5s	remaining: 3.63s
# 1027:	learn: 0.4114668	total: 24.6s	remaining: 3.61s
# 1028:	learn: 0.4114595	total: 24.6s	remaining: 3.59s
# 1029:	learn: 0.4114525	total: 24.7s	remaining: 3.57s
# 1030:	learn: 0.4114421	total: 24.7s	remaining: 3.55s
# 1031:	learn: 0.4114310	total: 24.8s	remaining: 3.53s
# 1032:	learn: 0.4114231	total: 24.8s	remaining: 3.5s
# 1033:	learn: 0.4114142	total: 24.8s	remaining: 3.48s
# 1034:	learn: 0.4114049	total: 24.9s	remaining: 3.46s
# 1035:	learn: 0.4113992	total: 24.9s	remaining: 3.44s
# 1036:	learn: 0.4113912	total: 24.9s	remaining: 3.41s
# 1037:	learn: 0.4113873	total: 25s	remaining: 3.39s
# 1038:	learn: 0.4113792	total: 25s	remaining: 3.37s
# 1039:	learn: 0.4113718	total: 25.1s	remaining: 3.35s
# 1040:	learn: 0.4113657	total: 25.1s	remaining: 3.33s
# 1041:	learn: 0.4113608	total: 25.1s	remaining: 3.31s
# 1042:	learn: 0.4113544	total: 25.2s	remaining: 3.28s
# 1043:	learn: 0.4113456	total: 25.2s	remaining: 3.26s
# 1044:	learn: 0.4113398	total: 25.3s	remaining: 3.24s
# 1045:	learn: 0.4113313	total: 25.3s	remaining: 3.22s
# 1046:	learn: 0.4113236	total: 25.3s	remaining: 3.19s
# 1047:	learn: 0.4113143	total: 25.4s	remaining: 3.17s
# 1048:	learn: 0.4113023	total: 25.4s	remaining: 3.15s
# 1049:	learn: 0.4112953	total: 25.5s	remaining: 3.13s
# 1050:	learn: 0.4112902	total: 25.5s	remaining: 3.11s
# 1051:	learn: 0.4112800	total: 25.6s	remaining: 3.09s
# 1052:	learn: 0.4112735	total: 25.6s	remaining: 3.06s
# 1053:	learn: 0.4112656	total: 25.6s	remaining: 3.04s
# 1054:	learn: 0.4112569	total: 25.7s	remaining: 3.02s
# 1055:	learn: 0.4112475	total: 25.7s	remaining: 3s
# 1056:	learn: 0.4112428	total: 25.8s	remaining: 2.97s
# 1057:	learn: 0.4112364	total: 25.8s	remaining: 2.95s
# 1058:	learn: 0.4112261	total: 25.9s	remaining: 2.93s
# 1059:	learn: 0.4112181	total: 25.9s	remaining: 2.91s
# 1060:	learn: 0.4112142	total: 25.9s	remaining: 2.88s
# 1061:	learn: 0.4112088	total: 26s	remaining: 2.86s
# 1062:	learn: 0.4112016	total: 26s	remaining: 2.84s
# 1063:	learn: 0.4111936	total: 26.1s	remaining: 2.82s
# 1064:	learn: 0.4111877	total: 26.1s	remaining: 2.8s
# 1065:	learn: 0.4111832	total: 26.2s	remaining: 2.77s
# 1066:	learn: 0.4111769	total: 26.2s	remaining: 2.75s
# 1067:	learn: 0.4111695	total: 26.3s	remaining: 2.73s
# 1068:	learn: 0.4111622	total: 26.3s	remaining: 2.71s
# 1069:	learn: 0.4111507	total: 26.4s	remaining: 2.69s
# 1070:	learn: 0.4111435	total: 26.4s	remaining: 2.66s
# 1071:	learn: 0.4111332	total: 26.5s	remaining: 2.64s
# 1072:	learn: 0.4111232	total: 26.5s	remaining: 2.62s
# 1073:	learn: 0.4111129	total: 26.5s	remaining: 2.6s
# 1074:	learn: 0.4111085	total: 26.6s	remaining: 2.57s
# 1075:	learn: 0.4111010	total: 26.6s	remaining: 2.54s
# 1076:	learn: 0.4110925	total: 26.6s	remaining: 2.52s
# 1077:	learn: 0.4110853	total: 26.7s	remaining: 2.5s
# 1078:	learn: 0.4110796	total: 26.7s	remaining: 2.48s
# 1079:	learn: 0.4110679	total: 26.8s	remaining: 2.45s
# 1080:	learn: 0.4110606	total: 26.8s	remaining: 2.43s
# 1081:	learn: 0.4110552	total: 26.9s	remaining: 2.41s
# 1082:	learn: 0.4110511	total: 26.9s	remaining: 2.38s
# 1083:	learn: 0.4110423	total: 26.9s	remaining: 2.36s
# 1084:	learn: 0.4110379	total: 27s	remaining: 2.34s
# 1085:	learn: 0.4110325	total: 27s	remaining: 2.31s
# 1086:	learn: 0.4110242	total: 27.1s	remaining: 2.29s
# 1087:	learn: 0.4110182	total: 27.1s	remaining: 2.27s
# 1088:	learn: 0.4110113	total: 27.2s	remaining: 2.25s
# 1089:	learn: 0.4110047	total: 27.2s	remaining: 2.22s
# 1090:	learn: 0.4109984	total: 27.3s	remaining: 2.2s
# 1091:	learn: 0.4109899	total: 27.3s	remaining: 2.18s
# 1092:	learn: 0.4109811	total: 27.4s	remaining: 2.15s
# 1093:	learn: 0.4109731	total: 27.4s	remaining: 2.13s
# 1094:	learn: 0.4109669	total: 27.5s	remaining: 2.11s
# 1095:	learn: 0.4109558	total: 27.5s	remaining: 2.08s
# 1096:	learn: 0.4109496	total: 27.6s	remaining: 2.06s
# 1097:	learn: 0.4109414	total: 27.6s	remaining: 2.04s
# 1098:	learn: 0.4109343	total: 27.6s	remaining: 2.01s
# 1099:	learn: 0.4109261	total: 27.7s	remaining: 1.99s
# 1100:	learn: 0.4109203	total: 27.7s	remaining: 1.97s
# 1101:	learn: 0.4109140	total: 27.8s	remaining: 1.94s
# 1102:	learn: 0.4109095	total: 27.8s	remaining: 1.92s
# 1103:	learn: 0.4109064	total: 27.9s	remaining: 1.89s
# 1104:	learn: 0.4108986	total: 27.9s	remaining: 1.87s
# 1105:	learn: 0.4108891	total: 27.9s	remaining: 1.84s
# 1106:	learn: 0.4108832	total: 27.9s	remaining: 1.82s
# 1107:	learn: 0.4108741	total: 28s	remaining: 1.79s
# 1108:	learn: 0.4108676	total: 28s	remaining: 1.77s
# 1109:	learn: 0.4108604	total: 28.1s	remaining: 1.74s
# 1110:	learn: 0.4108566	total: 28.1s	remaining: 1.72s
# 1111:	learn: 0.4108519	total: 28.1s	remaining: 1.69s
# 1112:	learn: 0.4108467	total: 28.1s	remaining: 1.67s
# 1113:	learn: 0.4108420	total: 28.2s	remaining: 1.64s
# 1114:	learn: 0.4108327	total: 28.2s	remaining: 1.62s
# 1115:	learn: 0.4108253	total: 28.3s	remaining: 1.59s
# 1116:	learn: 0.4108208	total: 28.3s	remaining: 1.57s
# 1117:	learn: 0.4108121	total: 28.3s	remaining: 1.55s
# 1118:	learn: 0.4108052	total: 28.4s	remaining: 1.52s
# 1119:	learn: 0.4107986	total: 28.4s	remaining: 1.5s
# 1120:	learn: 0.4107915	total: 28.4s	remaining: 1.47s
# 1121:	learn: 0.4107861	total: 28.5s	remaining: 1.45s
# 1122:	learn: 0.4107791	total: 28.5s	remaining: 1.42s
# 1123:	learn: 0.4107740	total: 28.5s	remaining: 1.4s
# 1124:	learn: 0.4107679	total: 28.6s	remaining: 1.37s
# 1125:	learn: 0.4107633	total: 28.6s	remaining: 1.34s
# 1126:	learn: 0.4107527	total: 28.6s	remaining: 1.32s
# 1127:	learn: 0.4107428	total: 28.6s	remaining: 1.29s
# 1128:	learn: 0.4107381	total: 28.7s	remaining: 1.27s
# 1129:	learn: 0.4107284	total: 28.7s	remaining: 1.24s
# 1130:	learn: 0.4107230	total: 28.7s	remaining: 1.22s
# 1131:	learn: 0.4107191	total: 28.8s	remaining: 1.19s
# 1132:	learn: 0.4107141	total: 28.8s	remaining: 1.17s
# 1133:	learn: 0.4107077	total: 28.8s	remaining: 1.14s
# 1134:	learn: 0.4106976	total: 28.9s	remaining: 1.12s
# 1135:	learn: 0.4106924	total: 28.9s	remaining: 1.09s
# 1136:	learn: 0.4106840	total: 28.9s	remaining: 1.07s
# 1137:	learn: 0.4106788	total: 29s	remaining: 1.04s
# 1138:	learn: 0.4106732	total: 29s	remaining: 1.02s
# 1139:	learn: 0.4106658	total: 29s	remaining: 994ms
# 1140:	learn: 0.4106606	total: 29.1s	remaining: 968ms
# 1141:	learn: 0.4106555	total: 29.1s	remaining: 943ms
# 1142:	learn: 0.4106496	total: 29.1s	remaining: 918ms
# 1143:	learn: 0.4106431	total: 29.2s	remaining: 892ms
# 1144:	learn: 0.4106353	total: 29.2s	remaining: 867ms
# 1145:	learn: 0.4106284	total: 29.2s	remaining: 842ms
# 1146:	learn: 0.4106261	total: 29.3s	remaining: 816ms
# 1147:	learn: 0.4106181	total: 29.3s	remaining: 791ms
# 1148:	learn: 0.4106106	total: 29.3s	remaining: 765ms
# 1149:	learn: 0.4106048	total: 29.3s	remaining: 739ms
# 1150:	learn: 0.4105989	total: 29.3s	remaining: 714ms
# 1151:	learn: 0.4105907	total: 29.4s	remaining: 688ms
# 1152:	learn: 0.4105821	total: 29.4s	remaining: 663ms
# 1153:	learn: 0.4105746	total: 29.4s	remaining: 637ms
# 1154:	learn: 0.4105689	total: 29.4s	remaining: 611ms
# 1155:	learn: 0.4105633	total: 29.4s	remaining: 586ms
# 1156:	learn: 0.4105527	total: 29.5s	remaining: 560ms
# 1157:	learn: 0.4105453	total: 29.5s	remaining: 534ms
# 1158:	learn: 0.4105355	total: 29.5s	remaining: 509ms
# 1159:	learn: 0.4105251	total: 29.5s	remaining: 483ms
# 1160:	learn: 0.4105205	total: 29.5s	remaining: 458ms
# 1161:	learn: 0.4105154	total: 29.6s	remaining: 432ms
# 1162:	learn: 0.4105088	total: 29.6s	remaining: 407ms
# 1163:	learn: 0.4105015	total: 29.6s	remaining: 381ms
# 1164:	learn: 0.4104913	total: 29.6s	remaining: 356ms
# 1165:	learn: 0.4104832	total: 29.6s	remaining: 330ms
# 1166:	learn: 0.4104779	total: 29.7s	remaining: 305ms
# 1167:	learn: 0.4104732	total: 29.7s	remaining: 279ms
# 1168:	learn: 0.4104675	total: 29.7s	remaining: 254ms
# 1169:	learn: 0.4104604	total: 29.7s	remaining: 229ms
# 1170:	learn: 0.4104505	total: 29.7s	remaining: 203ms
# 1171:	learn: 0.4104468	total: 29.8s	remaining: 178ms
# 1172:	learn: 0.4104388	total: 29.8s	remaining: 152ms
# 1173:	learn: 0.4104325	total: 29.8s	remaining: 127ms
# 1174:	learn: 0.4104283	total: 29.8s	remaining: 101ms
# 1175:	learn: 0.4104194	total: 29.8s	remaining: 76.1ms
# 1176:	learn: 0.4104106	total: 29.8s	remaining: 50.7ms
# 1177:	learn: 0.4104057	total: 29.9s	remaining: 25.4ms
# 1178:	learn: 0.4103965	total: 29.9s	remaining: 0us
# 80번 시드 : 0.1579265075420525

# %%
from scipy.stats.mstats import gmean

seed_pred = []
for idx, seed in tqdm(enumerate(cat_seeds)):
    pred_list=[]
    for model in tqdm(SEED_models[idx]):
        pred = model.predict(test_x)
        pred = np.expm1(pred)
        pred_list.append(pred)
    pred_mean = gmean(pred_list)
    seed_pred.append(pred_mean)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
cat_df = pd.DataFrame(seed_pred).transpose()
cat_df
# Out:
#               0         1         2         3         4
# 0      4.080912  4.175876  4.167483  4.201240  4.171215
# 1      3.462164  3.523568  3.491668  3.481124  3.509346
# 2      4.229878  4.274538  4.274009  4.258158  4.287707
# 3      4.018405  3.999090  4.034586  4.020797  4.036647
# 4      4.478138  4.441653  4.466604  4.445593  4.448372
# ...         ...       ...       ...       ...       ...
# 10958  5.812477  5.822988  5.845697  5.850682  5.919208
# 10959  3.695803  3.700527  3.700118  3.686473  3.679137
# 10960  3.735238  3.771344  3.745777  3.746905  3.749600
# 10961  4.732894  4.678849  4.742485  4.744147  4.672201
# 10962  4.567874  4.523934  4.563257  4.531446  4.539251
#
# [10963 rows x 5 columns]

# %%
cat_df.to_csv(f'{DATA_PATH}cat_df.csv', index=False)

# %%
pd.concat([lgbm_df, xgb_df, cat_df], axis=1)
# Out:
#               0         1         2         3         4         0         1  \
# 0      4.150018  4.138337  4.207658  4.191461  4.192837  4.128914  4.204660
# 1      3.694634  3.687554  3.702671  3.711184  3.713311  3.668110  3.647670
# 2      4.358323  4.394766  4.369254  4.332526  4.401976  4.358341  4.356406
# 3      4.129458  4.148096  4.109636  4.099398  4.121746  4.092301  4.068682
# 4      4.444787  4.513446  4.477486  4.447603  4.461015  4.545054  4.582445
# ...         ...       ...       ...       ...       ...       ...       ...
# 10958  5.742023  5.748411  5.716561  5.730869  5.810464  5.771307  5.758663
# 10959  3.632046  3.624980  3.640800  3.646214  3.616477  3.673392  3.670820
# 10960  3.731874  3.693681  3.745944  3.729047  3.706513  3.731966  3.730936
# 10961  4.633593  4.645425  4.644879  4.667253  4.672577  4.664433  4.632857
# 10962  4.591814  4.606289  4.608370  4.626428  4.608409  4.523620  4.559039
#
#               2         3         4         0         1         2         3  \
# 0      4.201684  4.162585  4.156024  4.080912  4.175876  4.167483  4.201240
# 1      3.720807  3.660049  3.718945  3.462164  3.523568  3.491668  3.481124
# 2      4.375614  4.383730  4.366761  4.229878  4.274538  4.274009  4.258158
# 3      4.095982  4.021044  4.107259  4.018405  3.999090  4.034586  4.020797
# 4      4.542928  4.571039  4.521232  4.478138  4.441653  4.466604  4.445593
# ...         ...       ...       ...       ...       ...       ...       ...
# 10958  5.748721  5.832650  5.771062  5.812477  5.822988  5.845697  5.850682
# 10959  3.709404  3.686374  3.706645  3.695803  3.700527  3.700118  3.686473
# 10960  3.764326  3.737476  3.786582  3.735238  3.771344  3.745777  3.746905
# 10961  4.685436  4.645179  4.618321  4.732894  4.678849  4.742485  4.744147
# 10962  4.520933  4.529456  4.499360  4.567874  4.523934  4.563257  4.531446
#
#               4
# 0      4.171215
# 1      3.509346
# 2      4.287707
# 3      4.036647
# 4      4.448372
# ...         ...
# 10958  5.919208
# 10959  3.679137
# 10960  3.749600
# 10961  4.672201
# 10962  4.539251
#
# [10963 rows x 15 columns]

# %%
pred_df = pd.concat([lgbm_df, xgb_df, cat_df], axis=1)

# %%
pred_df
# Out:
#               0         1         2         3         4         0         1  \
# 0      4.150018  4.138337  4.207658  4.191461  4.192837  4.128914  4.204660
# 1      3.694634  3.687554  3.702671  3.711184  3.713311  3.668110  3.647670
# 2      4.358323  4.394766  4.369254  4.332526  4.401976  4.358341  4.356406
# 3      4.129458  4.148096  4.109636  4.099398  4.121746  4.092301  4.068682
# 4      4.444787  4.513446  4.477486  4.447603  4.461015  4.545054  4.582445
# ...         ...       ...       ...       ...       ...       ...       ...
# 10958  5.742023  5.748411  5.716561  5.730869  5.810464  5.771307  5.758663
# 10959  3.632046  3.624980  3.640800  3.646214  3.616477  3.673392  3.670820
# 10960  3.731874  3.693681  3.745944  3.729047  3.706513  3.731966  3.730936
# 10961  4.633593  4.645425  4.644879  4.667253  4.672577  4.664433  4.632857
# 10962  4.591814  4.606289  4.608370  4.626428  4.608409  4.523620  4.559039
#
#               2         3         4         0         1         2         3  \
# 0      4.201684  4.162585  4.156024  4.080912  4.175876  4.167483  4.201240
# 1      3.720807  3.660049  3.718945  3.462164  3.523568  3.491668  3.481124
# 2      4.375614  4.383730  4.366761  4.229878  4.274538  4.274009  4.258158
# 3      4.095982  4.021044  4.107259  4.018405  3.999090  4.034586  4.020797
# 4      4.542928  4.571039  4.521232  4.478138  4.441653  4.466604  4.445593
# ...         ...       ...       ...       ...       ...       ...       ...
# 10958  5.748721  5.832650  5.771062  5.812477  5.822988  5.845697  5.850682
# 10959  3.709404  3.686374  3.706645  3.695803  3.700527  3.700118  3.686473
# 10960  3.764326  3.737476  3.786582  3.735238  3.771344  3.745777  3.746905
# 10961  4.685436  4.645179  4.618321  4.732894  4.678849  4.742485  4.744147
# 10962  4.520933  4.529456  4.499360  4.567874  4.523934  4.563257  4.531446
#
#               4
# 0      4.171215
# 1      3.509346
# 2      4.287707
# 3      4.036647
# 4      4.448372
# ...         ...
# 10958  5.919208
# 10959  3.679137
# 10960  3.749600
# 10961  4.672201
# 10962  4.539251
#
# [10963 rows x 15 columns]

# %%
pred = gmean(pred_df.values, axis=1)
pred
# Out:
# array([4.16859122, 3.62488279, 4.33447158, ..., 3.74041303, 4.6718772 ,
#        4.55980233])

# %%
submission['ECLO'] = pred

# %%
submission
# Out:
#                    ID      ECLO
# 0      ACCIDENT_39609  4.168591
# 1      ACCIDENT_39610  3.624883
# 2      ACCIDENT_39611  4.334472
# 3      ACCIDENT_39612  4.073280
# 4      ACCIDENT_39613  4.492242
# ...               ...       ...
# 10958  ACCIDENT_50567  5.791869
# 10959  ACCIDENT_50568  3.671155
# 10960  ACCIDENT_50569  3.740413
# 10961  ACCIDENT_50570  4.671877
# 10962  ACCIDENT_50571  4.559802
#
# [10963 rows x 2 columns]

# %%
submission.to_csv('submission_ensemble_1203.csv', index=False)
